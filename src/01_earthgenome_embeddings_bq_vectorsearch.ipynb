# %% [markdown]
# ### Earth Genome uses the ESA tile system with a 5-digit identifier.
#
# ### In [00_s2_tile_management_sea.ipynb](./00_s2_tile_management_sea.ipynb) we've already aggregated tile IDs to country boundaries
#
# ### we'll use that JSON file to help us pull only the EG parquet files we need for a country..

# %% [markdown]
# ### Downloading Earthgenome Geoparquet's

# %%
# let's check how EG organized their data in the aws location
# !aws s3 ls s3://earthgenome/earthindexembeddings/2024/ --endpoint-url=https://data.source.coop

# %% [markdown]
# Read in our country-tile JSON reference

# %%
import os
import json
import geopandas as gpd
tile_dict = json.load(open("../esa_grid/adm0_tiles_by_country_SEA.json"))
print(tile_dict.keys())
# Out:
# dict_keys(['Cambodia', 'Indonesia', "Lao People's Democratic Republic", 'Malaysia', 'Myanmar', 'Philippines', 'Singapore', 'Thailand', 'Viet Nam'])

# %%
country = "Cambodia"
tiles = tile_dict[country]
tiles.sort()
print(f"{len(tiles)} S2 tiles covering {country}")
for t in tiles:
    print(t)
# Out:
# 36 S2 tiles covering Cambodia
# 47PRP
# 47PRQ
# 47PRR
# 48PTA
# 48PTR
# 48PTS
# 48PTT
# 48PTU
# 48PTV
# 48PUA
# 48PUB
# 48PUS
# 48PUT
# 48PUU
# 48PUV
# 48PVA
# 48PVB
# 48PVS
# 48PVT
# 48PVU
# 48PVV
# 48PWA
# 48PWS
# 48PWT
# 48PWU
# 48PWV
# 48PXA
# 48PXB
# 48PXS
# 48PXT
# 48PXU
# 48PXV
# 48PYA
# 48PYB
# 48PYU
# 48PYV

# %%
import subprocess

dryrun=True

for t in tiles:
    suffix = "2024-01-01_2025-01-01.parquet"
    pattern = f"s3://earthgenome/earthindexembeddings/2024/{t}_{suffix}"
    cmd = f"aws s3 cp {pattern} ../embeddings/earthgenome/2024/{t}_{suffix} --endpoint-url=https://data.source.coop"
    if dryrun:

        print(cmd)
    else:
        print(f"Running {cmd}")
        try:
            subprocess.run(cmd, shell=True, capture_output=True, check=True)
        except subprocess.CalledProcessError as e:
            print(f"Error copying {t}: {e}")
            # If the file does not exist, we can skip it
            if "does not exist" in e.stderr.decode():
                print(f"File {t} does not exist, skipping.")
                continue
            else:
                raise
    # break
# Out:
# aws s3 cp s3://earthgenome/earthindexembeddings/2024/47PRP_2024-01-01_2025-01-01.parquet ../embeddings/earthgenome/2024/47PRP_2024-01-01_2025-01-01.parquet --endpoint-url=https://data.source.coop
# aws s3 cp s3://earthgenome/earthindexembeddings/2024/47PRQ_2024-01-01_2025-01-01.parquet ../embeddings/earthgenome/2024/47PRQ_2024-01-01_2025-01-01.parquet --endpoint-url=https://data.source.coop
# aws s3 cp s3://earthgenome/earthindexembeddings/2024/47PRR_2024-01-01_2025-01-01.parquet ../embeddings/earthgenome/2024/47PRR_2024-01-01_2025-01-01.parquet --endpoint-url=https://data.source.coop
# aws s3 cp s3://earthgenome/earthindexembeddings/2024/48PTA_2024-01-01_2025-01-01.parquet ../embeddings/earthgenome/2024/48PTA_2024-01-01_2025-01-01.parquet --endpoint-url=https://data.source.coop
# aws s3 cp s3://earthgenome/earthindexembeddings/2024/48PTR_2024-01-01_2025-01-01.parquet ../embeddings/earthgenome/2024/48PTR_2024-01-01_2025-01-01.parquet --endpoint-url=https://data.source.coop
# aws s3 cp s3://earthgenome/earthindexembeddings/2024/48PTS_2024-01-01_2025-01-01.parquet ../embeddings/earthgenome/2024/48PTS_2024-01-01_2025-01-01.parquet --endpoint-url=https://data.source.coop
# aws s3 cp s3://earthgenome/earthindexembeddings/2024/48PTT_2024-01-01_2025-01-01.parquet ../embeddings/earthgenome/2024/48PTT_2024-01-01_2025-01-01.parquet --endpoint-url=https://data.source.coop
# aws s3 cp s3://earthgenome/earthindexembeddings/2024/48PTU_2024-01-01_2025-01-01.parquet ../embeddings/earthgenome/2024/48PTU_2024-01-01_2025-01-01.parquet --endpoint-url=https://data.source.coop
# aws s3 cp s3://earthgenome/earthindexembeddings/2024/48PTV_2024-01-01_2025-01-01.parquet ../embeddings/earthgenome/2024/48PTV_2024-01-01_2025-01-01.parquet --endpoint-url=https://data.source.coop
# aws s3 cp s3://earthgenome/earthindexembeddings/2024/48PUA_2024-01-01_2025-01-01.parquet ../embeddings/earthgenome/2024/48PUA_2024-01-01_2025-01-01.parquet --endpoint-url=https://data.source.coop
# aws s3 cp s3://earthgenome/earthindexembeddings/2024/48PUB_2024-01-01_2025-01-01.parquet ../embeddings/earthgenome/2024/48PUB_2024-01-01_2025-01-01.parquet --endpoint-url=https://data.source.coop
# aws s3 cp s3://earthgenome/earthindexembeddings/2024/48PUS_2024-01-01_2025-01-01.parquet ../embeddings/earthgenome/2024/48PUS_2024-01-01_2025-01-01.parquet --endpoint-url=https://data.source.coop
# aws s3 cp s3://earthgenome/earthindexembeddings/2024/48PUT_2024-01-01_2025-01-01.parquet ../embeddings/earthgenome/2024/48PUT_2024-01-01_2025-01-01.parquet --endpoint-url=https://data.source.coop
# aws s3 cp s3://earthgenome/earthindexembeddings/2024/48PUU_2024-01-01_2025-01-01.parquet ../embeddings/earthgenome/2024/48PUU_2024-01-01_2025-01-01.parquet --endpoint-url=https://data.source.coop
# aws s3 cp s3://earthgenome/earthindexembeddings/2024/48PUV_2024-01-01_2025-01-01.parquet ../embeddings/earthgenome/2024/48PUV_2024-01-01_2025-01-01.parquet --endpoint-url=https://data.source.coop
# aws s3 cp s3://earthgenome/earthindexembeddings/2024/48PVA_2024-01-01_2025-01-01.parquet ../embeddings/earthgenome/2024/48PVA_2024-01-01_2025-01-01.parquet --endpoint-url=https://data.source.coop
# aws s3 cp s3://earthgenome/earthindexembeddings/2024/48PVB_2024-01-01_2025-01-01.parquet ../embeddings/earthgenome/2024/48PVB_2024-01-01_2025-01-01.parquet --endpoint-url=https://data.source.coop
# aws s3 cp s3://earthgenome/earthindexembeddings/2024/48PVS_2024-01-01_2025-01-01.parquet ../embeddings/earthgenome/2024/48PVS_2024-01-01_2025-01-01.parquet --endpoint-url=https://data.source.coop
# aws s3 cp s3://earthgenome/earthindexembeddings/2024/48PVT_2024-01-01_2025-01-01.parquet ../embeddings/earthgenome/2024/48PVT_2024-01-01_2025-01-01.parquet --endpoint-url=https://data.source.coop
# aws s3 cp s3://earthgenome/earthindexembeddings/2024/48PVU_2024-01-01_2025-01-01.parquet ../embeddings/earthgenome/2024/48PVU_2024-01-01_2025-01-01.parquet --endpoint-url=https://data.source.coop
# aws s3 cp s3://earthgenome/earthindexembeddings/2024/48PVV_2024-01-01_2025-01-01.parquet ../embeddings/earthgenome/2024/48PVV_2024-01-01_2025-01-01.parquet --endpoint-url=https://data.source.coop
# aws s3 cp s3://earthgenome/earthindexembeddings/2024/48PWA_2024-01-01_2025-01-01.parquet ../embeddings/earthgenome/2024/48PWA_2024-01-01_2025-01-01.parquet --endpoint-url=https://data.source.coop
# aws s3 cp s3://earthgenome/earthindexembeddings/2024/48PWS_2024-01-01_2025-01-01.parquet ../embeddings/earthgenome/2024/48PWS_2024-01-01_2025-01-01.parquet --endpoint-url=https://data.source.coop
# aws s3 cp s3://earthgenome/earthindexembeddings/2024/48PWT_2024-01-01_2025-01-01.parquet ../embeddings/earthgenome/2024/48PWT_2024-01-01_2025-01-01.parquet --endpoint-url=https://data.source.coop
# aws s3 cp s3://earthgenome/earthindexembeddings/2024/48PWU_2024-01-01_2025-01-01.parquet ../embeddings/earthgenome/2024/48PWU_2024-01-01_2025-01-01.parquet --endpoint-url=https://data.source.coop
# aws s3 cp s3://earthgenome/earthindexembeddings/2024/48PWV_2024-01-01_2025-01-01.parquet ../embeddings/earthgenome/2024/48PWV_2024-01-01_2025-01-01.parquet --endpoint-url=https://data.source.coop
# aws s3 cp s3://earthgenome/earthindexembeddings/2024/48PXA_2024-01-01_2025-01-01.parquet ../embeddings/earthgenome/2024/48PXA_2024-01-01_2025-01-01.parquet --endpoint-url=https://data.source.coop
# aws s3 cp s3://earthgenome/earthindexembeddings/2024/48PXB_2024-01-01_2025-01-01.parquet ../embeddings/earthgenome/2024/48PXB_2024-01-01_2025-01-01.parquet --endpoint-url=https://data.source.coop
# aws s3 cp s3://earthgenome/earthindexembeddings/2024/48PXS_2024-01-01_2025-01-01.parquet ../embeddings/earthgenome/2024/48PXS_2024-01-01_2025-01-01.parquet --endpoint-url=https://data.source.coop
# aws s3 cp s3://earthgenome/earthindexembeddings/2024/48PXT_2024-01-01_2025-01-01.parquet ../embeddings/earthgenome/2024/48PXT_2024-01-01_2025-01-01.parquet --endpoint-url=https://data.source.coop
# aws s3 cp s3://earthgenome/earthindexembeddings/2024/48PXU_2024-01-01_2025-01-01.parquet ../embeddings/earthgenome/2024/48PXU_2024-01-01_2025-01-01.parquet --endpoint-url=https://data.source.coop
# aws s3 cp s3://earthgenome/earthindexembeddings/2024/48PXV_2024-01-01_2025-01-01.parquet ../embeddings/earthgenome/2024/48PXV_2024-01-01_2025-01-01.parquet --endpoint-url=https://data.source.coop
# aws s3 cp s3://earthgenome/earthindexembeddings/2024/48PYA_2024-01-01_2025-01-01.parquet ../embeddings/earthgenome/2024/48PYA_2024-01-01_2025-01-01.parquet --endpoint-url=https://data.source.coop
# aws s3 cp s3://earthgenome/earthindexembeddings/2024/48PYB_2024-01-01_2025-01-01.parquet ../embeddings/earthgenome/2024/48PYB_2024-01-01_2025-01-01.parquet --endpoint-url=https://data.source.coop
# aws s3 cp s3://earthgenome/earthindexembeddings/2024/48PYU_2024-01-01_2025-01-01.parquet ../embeddings/earthgenome/2024/48PYU_2024-01-01_2025-01-01.parquet --endpoint-url=https://data.source.coop
# aws s3 cp s3://earthgenome/earthindexembeddings/2024/48PYV_2024-01-01_2025-01-01.parquet ../embeddings/earthgenome/2024/48PYV_2024-01-01_2025-01-01.parquet --endpoint-url=https://data.source.coop

# %% [markdown]
# Look at a geoparquet file

# %%
# look at one
files = os.listdir("../embeddings/earthgenome/2024")
print(f"{len(list(files))} files:\n {files}")
file = os.path.join("../embeddings/earthgenome/2024", files[0])
print(file)
df = gpd.read_parquet(file)
print(df.head())
# Out:
# 36 files:
#  ['48PVS_2024-01-01_2025-01-01.parquet', '48PYB_2024-01-01_2025-01-01.parquet', '48PXS_2024-01-01_2025-01-01.parquet', '48PUV_2024-01-01_2025-01-01.parquet', '48PXB_2024-01-01_2025-01-01.parquet', '48PVU_2024-01-01_2025-01-01.parquet', '48PYV_2024-01-01_2025-01-01.parquet', '48PWU_2024-01-01_2025-01-01.parquet', '48PWS_2024-01-01_2025-01-01.parquet', '48PUT_2024-01-01_2025-01-01.parquet', '48PUB_2024-01-01_2025-01-01.parquet', '48PTT_2024-01-01_2025-01-01.parquet', '48PUS_2024-01-01_2025-01-01.parquet', '47PRP_2024-01-01_2025-01-01.parquet', '48PYU_2024-01-01_2025-01-01.parquet', '48PYA_2024-01-01_2025-01-01.parquet', '48PWA_2024-01-01_2025-01-01.parquet', '48PVB_2024-01-01_2025-01-01.parquet', '48PXA_2024-01-01_2025-01-01.parquet', '48PVT_2024-01-01_2025-01-01.parquet', '48PVV_2024-01-01_2025-01-01.parquet', '48PXV_2024-01-01_2025-01-01.parquet', '48PTR_2024-01-01_2025-01-01.parquet', '48PUA_2024-01-01_2025-01-01.parquet', '47PRQ_2024-01-01_2025-01-01.parquet', '48PWV_2024-01-01_2025-01-01.parquet', '48PWT_2024-01-01_2025-01-01.parquet', '48PTV_2024-01-01_2025-01-01.parquet', '48PTA_2024-01-01_2025-01-01.parquet', '48PXT_2024-01-01_2025-01-01.parquet', '47PRR_2024-01-01_2025-01-01.parquet', '48PTS_2024-01-01_2025-01-01.parquet', '48PTU_2024-01-01_2025-01-01.parquet', '48PVA_2024-01-01_2025-01-01.parquet', '48PXU_2024-01-01_2025-01-01.parquet', '48PUU_2024-01-01_2025-01-01.parquet']
# ../embeddings/earthgenome/2024/48PVS_2024-01-01_2025-01-01.parquet
#                   id                                          embedding  \
# 0  31646144126408287  [4.21372, -0.47599944, 2.2734528, 1.9703406, 1...
# 1  31646144130651742  [4.2551923, -0.7167304, 2.658962, 0.3453492, 1...
# 2  31646144176805470  [4.234766, 0.004074624, 2.8566103, 0.62115043,...
# 3  31646144181179995  [4.007387, -0.4687737, 2.4155247, 0.657522, 1....
# 4  31646144193779291  [4.0800915, -0.44566143, 2.454309, 0.83217186,...
#
#                     geometry   tile
# 0  POINT (104.09029 9.86266)  48PVS
# 1   POINT (104.0932 9.86266)  48PVS
# 2  POINT (104.09612 9.86266)  48PVS
# 3  POINT (104.09904 9.86266)  48PVS
# 4  POINT (104.10196 9.86266)  48PVS

# %% [markdown]
# we'll add a tile column to help us stay organized

# %%
# overwrite all files to add tile column
for file in files:
    file_path = os.path.join("../embeddings/earthgenome/2024", file)
    df = gpd.read_parquet(file_path)
    df.loc[:,'tile'] = os.path.basename(file).split("_")[0]
    df.to_parquet(file_path, index=False)
    print(f"Updated {file} with tile column.")
# Out:
# Updated 48PVS_2024-01-01_2025-01-01.parquet with tile column.

# %%
print(gpd.read_parquet(file_path).head())
# Out:
#                   id                                          embedding  \
# 0  31646144126408287  [4.21372, -0.47599944, 2.2734528, 1.9703406, 1...
# 1  31646144130651742  [4.2551923, -0.7167304, 2.658962, 0.3453492, 1...
# 2  31646144176805470  [4.234766, 0.004074624, 2.8566103, 0.62115043,...
# 3  31646144181179995  [4.007387, -0.4687737, 2.4155247, 0.657522, 1....
# 4  31646144193779291  [4.0800915, -0.44566143, 2.454309, 0.83217186,...
#
#                     geometry   tile
# 0  POINT (104.09029 9.86266)  48PVS
# 1   POINT (104.0932 9.86266)  48PVS
# 2  POINT (104.09612 9.86266)  48PVS
# 3  POINT (104.09904 9.86266)  48PVS
# 4  POINT (104.10196 9.86266)  48PVS

# %% [markdown]
# ### Loading Data into BigQuery

# %%
# create new bucket
BUCKET = "gs://embeddings-sea"
PROJECT_ID = "g4g-eaas"
LOCATION = "us-central1"

# %%
# upload parquet files to gcs
# try gcloud storage sync..
gcloud_folder = f"{BUCKET}/earthgenome/2024"
# !gcloud storage rsync ../embeddings/earthgenome/2024 $gcloud_folder \
    --project=$PROJECT_ID
# Out:
# At file://../embeddings/earthgenome/2024/*, worker process 3209627 thread 135100769339200 listed 36...
# At gs://embeddings-sea/embeddings/earthgenome/2024/*, worker process 3209627 thread 135100769339200 listed 1...
# WARNING: Parallel composite upload was turned ON to get the best performance on
# uploading large objects. If you would like to opt-out and instead
# perform a normal upload, run:
# `gcloud config set storage/parallel_composite_upload_enabled False`
# If you would like to disable this warning, run:
# `gcloud config set storage/parallel_composite_upload_enabled True`
# Note that with parallel composite uploads, your object might be
# uploaded as a composite object
# (https://cloud.google.com/storage/docs/composite-objects), which means
# that any user who downloads your object will need to use crc32c
# checksums to verify data integrity. gcloud storage is capable of
# computing crc32c checksums, but this might pose a problem for other
# clients.
#
# Copying file://../embeddings/earthgenome/2024/47PRP_2024-01-01_2025-01-01.parquet to gs://embeddings-sea/embeddings/earthgenome/2024/47PRP_2024-01-01_2025-01-01.parquet
# Copying file://../embeddings/earthgenome/2024/47PRQ_2024-01-01_2025-01-01.parquet to gs://embeddings-sea/embeddings/earthgenome/2024/47PRQ_2024-01-01_2025-01-01.parquet
# Copying file://../embeddings/earthgenome/2024/47PRR_2024-01-01_2025-01-01.parquet to gs://embeddings-sea/embeddings/earthgenome/2024/47PRR_2024-01-01_2025-01-01.parquet
# Copying file://../embeddings/earthgenome/2024/48PTA_2024-01-01_2025-01-01.parquet to gs://embeddings-sea/embeddings/earthgenome/2024/48PTA_2024-01-01_2025-01-01.parquet
# Copying file://../embeddings/earthgenome/2024/48PTR_2024-01-01_2025-01-01.parquet to gs://embeddings-sea/embeddings/earthgenome/2024/48PTR_2024-01-01_2025-01-01.parquet
# Copying file://../embeddings/earthgenome/2024/48PTS_2024-01-01_2025-01-01.parquet to gs://embeddings-sea/embeddings/earthgenome/2024/48PTS_2024-01-01_2025-01-01.parquet
# Copying file://../embeddings/earthgenome/2024/48PTT_2024-01-01_2025-01-01.parquet to gs://embeddings-sea/embeddings/earthgenome/2024/48PTT_2024-01-01_2025-01-01.parquet
# Copying file://../embeddings/earthgenome/2024/48PTU_2024-01-01_2025-01-01.parquet to gs://embeddings-sea/embeddings/earthgenome/2024/48PTU_2024-01-01_2025-01-01.parquet
# Copying file://../embeddings/earthgenome/2024/48PTV_2024-01-01_2025-01-01.parquet to gs://embeddings-sea/embeddings/earthgenome/2024/48PTV_2024-01-01_2025-01-01.parquet
# Copying file://../embeddings/earthgenome/2024/48PUA_2024-01-01_2025-01-01.parquet to gs://embeddings-sea/embeddings/earthgenome/2024/48PUA_2024-01-01_2025-01-01.parquet
# Copying file://../embeddings/earthgenome/2024/48PUB_2024-01-01_2025-01-01.parquet to gs://embeddings-sea/embeddings/earthgenome/2024/48PUB_2024-01-01_2025-01-01.parquet
# Copying file://../embeddings/earthgenome/2024/48PUS_2024-01-01_2025-01-01.parquet to gs://embeddings-sea/embeddings/earthgenome/2024/48PUS_2024-01-01_2025-01-01.parquet
# Copying file://../embeddings/earthgenome/2024/48PUT_2024-01-01_2025-01-01.parquet to gs://embeddings-sea/embeddings/earthgenome/2024/48PUT_2024-01-01_2025-01-01.parquet
# Copying file://../embeddings/earthgenome/2024/48PUU_2024-01-01_2025-01-01.parquet to gs://embeddings-sea/embeddings/earthgenome/2024/48PUU_2024-01-01_2025-01-01.parquet
# Copying file://../embeddings/earthgenome/2024/48PUV_2024-01-01_2025-01-01.parquet to gs://embeddings-sea/embeddings/earthgenome/2024/48PUV_2024-01-01_2025-01-01.parquet
# Copying file://../embeddings/earthgenome/2024/48PVA_2024-01-01_2025-01-01.parquet to gs://embeddings-sea/embeddings/earthgenome/2024/48PVA_2024-01-01_2025-01-01.parquet
# Copying file://../embeddings/earthgenome/2024/48PVB_2024-01-01_2025-01-01.parquet to gs://embeddings-sea/embeddings/earthgenome/2024/48PVB_2024-01-01_2025-01-01.parquet
# Copying file://../embeddings/earthgenome/2024/48PVS_2024-01-01_2025-01-01.parquet to gs://embeddings-sea/embeddings/earthgenome/2024/48PVS_2024-01-01_2025-01-01.parquet
# Copying file://../embeddings/earthgenome/2024/48PVT_2024-01-01_2025-01-01.parquet to gs://embeddings-sea/embeddings/earthgenome/2024/48PVT_2024-01-01_2025-01-01.parquet
# Copying file://../embeddings/earthgenome/2024/48PVU_2024-01-01_2025-01-01.parquet to gs://embeddings-sea/embeddings/earthgenome/2024/48PVU_2024-01-01_2025-01-01.parquet
# Copying file://../embeddings/earthgenome/2024/48PVV_2024-01-01_2025-01-01.parquet to gs://embeddings-sea/embeddings/earthgenome/2024/48PVV_2024-01-01_2025-01-01.parquet
# Copying file://../embeddings/earthgenome/2024/48PWA_2024-01-01_2025-01-01.parquet to gs://embeddings-sea/embeddings/earthgenome/2024/48PWA_2024-01-01_2025-01-01.parquet
# Copying file://../embeddings/earthgenome/2024/48PWS_2024-01-01_2025-01-01.parquet to gs://embeddings-sea/embeddings/earthgenome/2024/48PWS_2024-01-01_2025-01-01.parquet
# Copying file://../embeddings/earthgenome/2024/48PWT_2024-01-01_2025-01-01.parquet to gs://embeddings-sea/embeddings/earthgenome/2024/48PWT_2024-01-01_2025-01-01.parquet
# Copying file://../embeddings/earthgenome/2024/48PWU_2024-01-01_2025-01-01.parquet to gs://embeddings-sea/embeddings/earthgenome/2024/48PWU_2024-01-01_2025-01-01.parquet
# Copying file://../embeddings/earthgenome/2024/48PWV_2024-01-01_2025-01-01.parquet to gs://embeddings-sea/embeddings/earthgenome/2024/48PWV_2024-01-01_2025-01-01.parquet
# Copying file://../embeddings/earthgenome/2024/48PXA_2024-01-01_2025-01-01.parquet to gs://embeddings-sea/embeddings/earthgenome/2024/48PXA_2024-01-01_2025-01-01.parquet
# Copying file://../embeddings/earthgenome/2024/48PXB_2024-01-01_2025-01-01.parquet to gs://embeddings-sea/embeddings/earthgenome/2024/48PXB_2024-01-01_2025-01-01.parquet
# Copying file://../embeddings/earthgenome/2024/48PXS_2024-01-01_2025-01-01.parquet to gs://embeddings-sea/embeddings/earthgenome/2024/48PXS_2024-01-01_2025-01-01.parquet
# Copying file://../embeddings/earthgenome/2024/48PXT_2024-01-01_2025-01-01.parquet to gs://embeddings-sea/embeddings/earthgenome/2024/48PXT_2024-01-01_2025-01-01.parquet
# Copying file://../embeddings/earthgenome/2024/48PXU_2024-01-01_2025-01-01.parquet to gs://embeddings-sea/embeddings/earthgenome/2024/48PXU_2024-01-01_2025-01-01.parquet
# Copying file://../embeddings/earthgenome/2024/48PXV_2024-01-01_2025-01-01.parquet to gs://embeddings-sea/embeddings/earthgenome/2024/48PXV_2024-01-01_2025-01-01.parquet
# Copying file://../embeddings/earthgenome/2024/48PYA_2024-01-01_2025-01-01.parquet to gs://embeddings-sea/embeddings/earthgenome/2024/48PYA_2024-01-01_2025-01-01.parquet
# Copying file://../embeddings/earthgenome/2024/48PYB_2024-01-01_2025-01-01.parquet to gs://embeddings-sea/embeddings/earthgenome/2024/48PYB_2024-01-01_2025-01-01.parquet
# Copying file://../embeddings/earthgenome/2024/48PYU_2024-01-01_2025-01-01.parquet to gs://embeddings-sea/embeddings/earthgenome/2024/48PYU_2024-01-01_2025-01-01.parquet
# Copying file://../embeddings/earthgenome/2024/48PYV_2024-01-01_2025-01-01.parquet to gs://embeddings-sea/embeddings/earthgenome/2024/48PYV_2024-01-01_2025-01-01.parquet
#   Completed files 288/36 | 12.3GiB/12.3GiB | 28.2MiB/s
#
# Average throughput: 4.0MiB/s

# %%
# load geoparquet file from gcs to bigquery
DATASET_ID = "embeddings_sea"
TABLE_ID = "earthgenome_cambodia"
FULL_TABLE = f"{PROJECT_ID}:{DATASET_ID}.{TABLE_ID}"
FOLDER = "earthgenome/2024"
print(FULL_TABLE)
for file in files:
    URI = f"{BUCKET}/{FOLDER}/{file}"

    print(URI)
    # !bq --location=$LOCATION --project_id=$PROJECT_ID \
            load \
                --source_format=PARQUET \
                $FULL_TABLE \
                $URI
# Out:
# g4g-eaas:embeddings_sea.earthgenome_cambodia
# gs://embeddings-sea/earthgenome/2024/48PVS_2024-01-01_2025-01-01.parquet
# Waiting on bqjob_r242c47c8c8509611_00000197319a72b8_1 ... (36s) Current status: DONE
# gs://embeddings-sea/earthgenome/2024/48PYB_2024-01-01_2025-01-01.parquet
# Waiting on bqjob_r72c0e1a5c9f5091d_00000197319b1505_1 ... (36s) Current status: DONE
# gs://embeddings-sea/earthgenome/2024/48PXS_2024-01-01_2025-01-01.parquet
# Waiting on bqjob_r343feb9fd97f1f9b_00000197319bb1b2_1 ... (35s) Current status: DONE
# gs://embeddings-sea/earthgenome/2024/48PUV_2024-01-01_2025-01-01.parquet
# Waiting on bqjob_r43aaab8565ba13f1_00000197319c4c2f_1 ... (35s) Current status: DONE
# gs://embeddings-sea/earthgenome/2024/48PXB_2024-01-01_2025-01-01.parquet
# Waiting on bqjob_r421595f151593996_00000197319ce7c0_1 ... (35s) Current status: DONE
# gs://embeddings-sea/earthgenome/2024/48PVU_2024-01-01_2025-01-01.parquet
# Waiting on bqjob_r45897fa0f5e5028d_00000197319d8234_1 ... (24s) Current status: DONE
# gs://embeddings-sea/earthgenome/2024/48PYV_2024-01-01_2025-01-01.parquet
# Waiting on bqjob_r2a8f72acabc73281_00000197319df257_1 ... (24s) Current status: DONE
# gs://embeddings-sea/earthgenome/2024/48PWU_2024-01-01_2025-01-01.parquet
# Waiting on bqjob_r61fa538c072cede3_00000197319e61bd_1 ... (35s) Current status: DONE
# gs://embeddings-sea/earthgenome/2024/48PWS_2024-01-01_2025-01-01.parquet
# Waiting on bqjob_r67517e408e469ee9_00000197319efce6_1 ... (25s) Current status: DONE
# gs://embeddings-sea/earthgenome/2024/48PUT_2024-01-01_2025-01-01.parquet
# Waiting on bqjob_r7c452d81a082b434_00000197319f6f83_1 ... (24s) Current status: DONE
# gs://embeddings-sea/earthgenome/2024/48PUB_2024-01-01_2025-01-01.parquet
# Waiting on bqjob_r301fa0cfd3bc467a_00000197319fdedb_1 ... (35s) Current status: DONE
# gs://embeddings-sea/earthgenome/2024/48PTT_2024-01-01_2025-01-01.parquet
# Waiting on bqjob_r1b419d06f50fa033_0000019731a0791c_1 ... (35s) Current status: DONE
# gs://embeddings-sea/earthgenome/2024/48PUS_2024-01-01_2025-01-01.parquet
# Waiting on bqjob_r1c0665b283bd31ef_0000019731a11771_1 ... (136s) Current status: DONE
# gs://embeddings-sea/earthgenome/2024/47PRP_2024-01-01_2025-01-01.parquet
# Waiting on bqjob_r564f76caa43c58c8_0000019731a34065_1 ... (35s) Current status: DONE
# gs://embeddings-sea/earthgenome/2024/48PYU_2024-01-01_2025-01-01.parquet
# Waiting on bqjob_r6aaeb3ff25af0311_0000019731a3db8f_1 ... (35s) Current status: DONE
# gs://embeddings-sea/earthgenome/2024/48PYA_2024-01-01_2025-01-01.parquet
# Waiting on bqjob_r20fdf5d3a2bc7c7b_0000019731a477bc_1 ... (23s) Current status: DONE
# gs://embeddings-sea/earthgenome/2024/48PWA_2024-01-01_2025-01-01.parquet
# Waiting on bqjob_r7eb2d8d937e34b18_0000019731a4e680_1 ... (24s) Current status: DONE
# gs://embeddings-sea/earthgenome/2024/48PVB_2024-01-01_2025-01-01.parquet
# Waiting on bqjob_red20d6b3f380fd1_0000019731a554eb_1 ... (49s) Current status: DONE
# gs://embeddings-sea/earthgenome/2024/48PXA_2024-01-01_2025-01-01.parquet
# Waiting on bqjob_r7ef159da34bd9aec_0000019731a62637_1 ... (24s) Current status: DONE
# gs://embeddings-sea/earthgenome/2024/48PVT_2024-01-01_2025-01-01.parquet
# Waiting on bqjob_r6cb013cfb2590a4b_0000019731a69574_1 ... (23s) Current status: DONE
# gs://embeddings-sea/earthgenome/2024/48PVV_2024-01-01_2025-01-01.parquet
# Waiting on bqjob_r37ec8e47386ee6aa_0000019731a7036e_1 ... (15s) Current status: DONE
# gs://embeddings-sea/earthgenome/2024/48PXV_2024-01-01_2025-01-01.parquet
# Waiting on bqjob_r4145cf31e141a234_0000019731a74f7e_1 ... (24s) Current status: DONE
# gs://embeddings-sea/earthgenome/2024/48PTR_2024-01-01_2025-01-01.parquet
# Waiting on bqjob_r7bcb02143e12a821_0000019731a7be8f_1 ... (23s) Current status: DONE
# gs://embeddings-sea/earthgenome/2024/48PUA_2024-01-01_2025-01-01.parquet
# Waiting on bqjob_r4280d028aa293d13_0000019731a82a6b_1 ... (23s) Current status: DONE
# gs://embeddings-sea/earthgenome/2024/47PRQ_2024-01-01_2025-01-01.parquet
# Waiting on bqjob_r2ea4535e17107896_0000019731a898f4_1 ... (24s) Current status: DONE
# gs://embeddings-sea/earthgenome/2024/48PWV_2024-01-01_2025-01-01.parquet
# Waiting on bqjob_r5572e8bb388dc4da_0000019731a907b2_1 ... (24s) Current status: DONE
# gs://embeddings-sea/earthgenome/2024/48PWT_2024-01-01_2025-01-01.parquet
# Waiting on bqjob_r7364618171e56b21_0000019731a97633_1 ... (23s) Current status: DONE
# gs://embeddings-sea/earthgenome/2024/48PTV_2024-01-01_2025-01-01.parquet
# Waiting on bqjob_r33e43fed479b1e0_0000019731a9e234_1 ... (24s) Current status: DONE
# gs://embeddings-sea/earthgenome/2024/48PTA_2024-01-01_2025-01-01.parquet
# Waiting on bqjob_rb0bfd617e232e98_0000019731aa5022_1 ... (23s) Current status: DONE
# gs://embeddings-sea/earthgenome/2024/48PXT_2024-01-01_2025-01-01.parquet
# Waiting on bqjob_r6961ec726bce61f6_0000019731aabbf5_1 ... (24s) Current status: DONE
# gs://embeddings-sea/earthgenome/2024/47PRR_2024-01-01_2025-01-01.parquet
# Waiting on bqjob_r3b2e8b515c81b075_0000019731ab29b8_1 ... (23s) Current status: DONE
# gs://embeddings-sea/earthgenome/2024/48PTS_2024-01-01_2025-01-01.parquet
# Waiting on bqjob_re4def3a2f1c173d_0000019731ab95cd_1 ... (23s) Current status: DONE
# gs://embeddings-sea/earthgenome/2024/48PTU_2024-01-01_2025-01-01.parquet
# Waiting on bqjob_r23f1602a58d66d9b_0000019731ac02ee_1 ... (23s) Current status: DONE
# gs://embeddings-sea/earthgenome/2024/48PVA_2024-01-01_2025-01-01.parquet
# Waiting on bqjob_r3c9e186b6e9583ed_0000019731ac6f50_1 ... (23s) Current status: DONE
# gs://embeddings-sea/earthgenome/2024/48PXU_2024-01-01_2025-01-01.parquet
# Waiting on bqjob_r4164782e196d91ed_0000019731acdc03_1 ... (24s) Current status: DONE
# gs://embeddings-sea/earthgenome/2024/48PUU_2024-01-01_2025-01-01.parquet
# Waiting on bqjob_r51e54685babc98a5_0000019731ad4c50_1 ... (23s) Current status: DONE

# %% [markdown]
# ### Minor transforms of the BQ table
#
# n do a small post-processing query to get the embedding field converted correctly for vector search..
#
# vector search indexing requires the embedding field to be of type `ARRAY<FLOAT>`
#
# the load operation turns 'embedding' field into a double-nested STRUCT data type, innermost child containing list of floats..
#
# so we have to unpack that list from the nested structure, final data type being `ARRAY<FLOAT64>`

# %%
from google.cloud import bigquery
query = f"""
SELECT
  eg.id,
  eg.tile,
  ST_GEOGFROMTEXT(grouped.geometry_text) AS geometry,
  ARRAY_AGG(e.element) AS embedding
FROM
  `{PROJECT_ID}`.`{DATASET_ID}`.`{TABLE_ID}` AS eg
CROSS JOIN
  UNNEST(eg.embedding.list) AS e
JOIN (
  SELECT id, tile, ST_ASTEXT(geometry) AS geometry_text
  FROM `{PROJECT_ID}`.`{DATASET_ID}`.`{TABLE_ID}`
  GROUP BY id, tile, geometry_text
) AS grouped ON eg.id = grouped.id AND eg.tile = grouped.tile AND ST_ASTEXT(eg.geometry) = grouped.geometry_text
GROUP BY eg.id, eg.tile, grouped.geometry_text
"""

# Run the query and save the result to a new table
result_table = f"{PROJECT_ID}.{DATASET_ID}.earthgenome_cambodia_v1"
job_config = bigquery.QueryJobConfig(destination=result_table)
client = bigquery.Client()
job = client.query(query, job_config=job_config)
job.result()  # Wait for the job to complete

# %%
# Check if the result_table exists

def table_exists(client, table_id):
    try:
        client.get_table(table_id)
        print(f"Table {table_id} exists.")
        return True
    except Exception as e:
        print(f"Table {table_id} does not exist. Error: {e}")
        return False

table_exists(client, result_table)
# Out:
# Table g4g-eaas.embeddings_sea.earthgenome_cambodia_v1 exists.
# True

# %%
# check the resulting table's schema and data
query = f"SELECT * FROM `{result_table}` LIMIT 10"
query_job = client.query(query)
# print schema
schema = query_job.result().schema
for field in schema:
    print(f"{field.name}: {field.field_type}")
for row in query_job:
    print(row)
# Out:
# id: INTEGER
# tile: STRING
# geometry: GEOGRAPHY
# embedding: FLOAT
# Row((31736946848215620, '47PRP', 'POINT(101.915459844242 12.0042160401163)', [4.323385715484619, 0.06400411576032639, 1.0368335247039795, 1.5289827585220337, 1.4563442468643188, -2.2122995853424072, 4.070167064666748, -0.6424505710601807, 3.405003547668457, 1.4932760000228882, 1.7559279203414917, -1.833122730255127, -0.7179238796234131, -0.41533586382865906, 0.10614579916000366, 0.00683737313374877, 0.3592619299888611, 0.36866050958633423, -2.5919840335845947, 1.8089570999145508, 2.2521915435791016, 0.4613773226737976, 1.5383117198944092, -3.08720064163208, -0.7681889533996582, 0.8207824230194092, 0.819365918636322, 1.1905938386917114, -1.2695367336273193, 2.3134665489196777, -1.4144809246063232, -0.4272822141647339, -1.8325029611587524, 0.38100242614746094, -0.9554205536842346, -1.8019816875457764, 0.023497002199292183, 1.0904444456100464, 0.07832003384828568, 0.4823470115661621, 0.007036820985376835, -0.48182833194732666, -1.824415922164917, -2.077702760696411, 0.2267729640007019, 2.6559743881225586, 0.5945883989334106, -0.5629788041114807, 0.41543784737586975, 1.832758903503418, -0.4281490743160248, 2.259654998779297, 0.30134791135787964, -1.5777615308761597, -3.5840423107147217, -0.6627023816108704, 1.6278167963027954, -1.1058237552642822, 0.3934516906738281, -1.3013919591903687, -2.278557538986206, -1.0269848108291626, 1.266557216644287, -0.5237935185432434, 2.2278194427490234, -1.2035952806472778, 0.21114614605903625, -2.8711395263671875, -0.012479269877076149, -1.9781887531280518, 0.40023642778396606, 1.9923882484436035, 0.7879493236541748, 1.1221035718917847, 1.7537161111831665, -3.5998001098632812, -1.592292308807373, 0.6130182147026062, -2.8970632553100586, -5.522192001342773, -0.8975423574447632, 0.8300317525863647, -1.9119595289230347, -1.3739267587661743, 1.6591516733169556, 2.279778242111206, 3.3665881156921387, -0.5729910135269165, -1.733843445777893, -1.8768625259399414, 0.38844597339630127, -1.0050941705703735, 0.9490702748298645, 1.3800106048583984, 1.0204172134399414, -1.5944926738739014, -1.157505989074707, -1.5972508192062378, -0.14135055243968964, 0.6976481676101685, -0.5822269320487976, 1.292502760887146, -0.32405784726142883, 1.2890570163726807, 1.419417381286621, -0.36789777874946594, 0.6513198018074036, 0.6325297355651855, 3.914031505584717, 1.8078161478042603, 0.539600133895874, 0.7935558557510376, 0.9501410722732544, 0.8405017256736755, 2.1679317951202393, -0.003045958001166582, -2.1595635414123535, -0.6044034957885742, 1.605846643447876, 0.6951437592506409, -0.9027624726295471, 1.1047242879867554, -0.16403953731060028, -0.12011823058128357, 0.18217235803604126, 0.9535537362098694, 0.43430450558662415, -2.2709550857543945, -1.2018301486968994, -0.11480098217725754, -1.4744443893432617, -1.353990912437439, 1.8456670045852661, 0.5620413422584534, -3.519312620162964, 0.742499828338623, 0.16434399783611298, -0.5351830720901489, 9.471142768859863, 0.562960147857666, 0.9286086559295654, 1.151094675064087, 0.8118848204612732, 0.18991215527057648, 0.587012529373169, -1.3410793542861938, 1.688963770866394, -1.1560629606246948, -1.9051909446716309, 3.3512179851531982, -1.628217339515686, -2.387059450149536, -0.7870654463768005, 3.2620532512664795, 0.4962363541126251, 1.3192311525344849, 1.134405255317688, -3.780400514602661, 0.92930006980896, 0.23833487927913666, -1.1298030614852905, 2.6660664081573486, -0.5052807331085205, 0.6200173497200012, -5.016231536865234, -1.6375471353530884, -0.2662550210952759, 0.39435189962387085, -1.0373414754867554, 2.859299421310425, -0.635350227355957, -0.5168043971061707, 0.30751708149909973, -0.5177436470985413, 0.7093954682350159, -0.311345636844635, 1.8463449478149414, 0.17929129302501678, -1.6578341722488403, 0.24201542139053345, -1.2768447399139404, 0.48511815071105957, -2.3227617740631104, -0.2862094044685364, -0.4156416952610016, 0.46517106890678406, -2.340461492538452, 2.1179981231689453, -1.6074154376983643, 2.5151584148406982, -1.2705410718917847, 0.175815612077713,  ...
# Row((31736719386274932, '47PRP', 'POINT(102.017904314646 11.657830016928)', [5.345119476318359, -0.15011873841285706, 1.3378127813339233, 1.1903072595596313, 2.0997207164764404, -1.311848759651184, 3.680324077606201, 0.03941407427191734, 3.3459105491638184, 1.1150023937225342, 1.1385549306869507, -2.408017873764038, 0.5170308947563171, 0.24601240456104279, -0.6125040054321289, 0.4505045711994171, 0.09098315238952637, 0.4311924874782562, -2.348893880844116, 1.7807915210723877, 1.9073001146316528, 0.3894188702106476, 0.885414719581604, -2.8824925422668457, -1.4732005596160889, 0.28047576546669006, -0.03045688010752201, -0.36530351638793945, -0.6817325353622437, 4.136542320251465, -1.843156337738037, -1.325393557548523, -2.320927143096924, 0.7673675417900085, -0.6767612099647522, -1.0927836894989014, -0.9427685141563416, 0.28446823358535767, 0.16937856376171112, 1.1100026369094849, -0.6953509449958801, 0.005008556414395571, -0.6526694893836975, -1.2906228303909302, 1.2790330648422241, 2.9969584941864014, 0.5612828731536865, -0.19602665305137634, 0.11445590108633041, 1.2942949533462524, 0.7474538683891296, 2.2419793605804443, -0.3090859651565552, -1.064756989479065, -3.5055019855499268, -0.5488674640655518, 1.7274718284606934, -1.3397774696350098, -0.17054836452007294, -1.3456140756607056, -1.6207572221755981, -1.8734146356582642, 1.8353811502456665, -0.23447668552398682, 1.9870961904525757, -0.18597374856472015, -0.8461300730705261, -2.8725850582122803, -0.13217400014400482, -1.4907376766204834, -0.11503706872463226, 1.7052428722381592, 0.06958165764808655, 1.2908600568771362, 2.108602523803711, -2.7212467193603516, -1.208522081375122, 0.7286234498023987, -2.0025794506073, -5.236602306365967, -0.6966275572776794, 1.3682721853256226, -2.744821548461914, -1.2187912464141846, 1.8264974355697632, 3.2842931747436523, 3.1141703128814697, -1.6496520042419434, -2.4692320823669434, -3.110525131225586, 0.29274412989616394, -2.068117618560791, 1.2628824710845947, 0.05514663830399513, 0.9807825684547424, -1.3011293411254883, -0.5825397372245789, -0.8852071762084961, -0.6738775968551636, 0.12381590902805328, -0.32704177498817444, 2.195279121398926, -0.966647207736969, 0.3809255063533783, 0.7740533351898193, -0.355370432138443, 1.314929485321045, 0.30601632595062256, 2.6489758491516113, 1.583091139793396, -0.09514252841472626, 1.084078311920166, 0.8498790860176086, 1.163662314414978, 2.268644332885742, -0.11354649811983109, -1.6560313701629639, -0.45941323041915894, 1.1484094858169556, 0.5723113417625427, -0.5177525877952576, 1.1205801963806152, 0.06712539494037628, -0.549876868724823, 0.8821390867233276, 1.475866436958313, 0.93910813331604, -2.4388575553894043, -0.9561456441879272, -0.2982078790664673, -0.4511716961860657, -2.114781618118286, 2.0760719776153564, -0.3919547498226166, -3.8790900707244873, -0.29961633682250977, -0.22106119990348816, -0.9092434644699097, 9.320297241210938, 0.9786550998687744, 1.2503522634506226, 0.5666735172271729, 0.11935847252607346, -0.11255253851413727, -0.1123570054769516, 0.10049380362033844, 2.350614070892334, -0.7657888531684875, -1.8203645944595337, 3.956303596496582, -1.5426630973815918, -2.2298121452331543, -0.27296605706214905, 2.8938889503479004, 0.4107954204082489, 1.2461621761322021, 0.3958427309989929, -3.5974738597869873, 0.5506798028945923, -0.6948462128639221, -0.69817054271698, 1.9188941717147827, -0.022748667746782303, 0.3827216923236847, -4.800694465637207, -3.5492866039276123, -0.496726393699646, -0.1269780695438385, -1.5172353982925415, 2.0282034873962402, -0.24084633588790894, -0.41976040601730347, 0.6595999002456665, -0.2938966751098633, -0.18938255310058594, -0.5341042876243591, 1.652561902999878, 0.34652015566825867, -1.8821215629577637, 0.38779231905937195, -1.0106457471847534, 1.1948614120483398, -2.844468593597412, -0.05408621206879616, 0.07117477804422379, 0.04209433123469353, -1.6713156700134277, 3.477343797683716, -1.7952383756637573, 2.275775194168091, -2.0113272666931152, 0.767 ...
# Row((31737080856092029, '47PRP', 'POINT(101.854419410745 12.3807850777732)', [4.3269195556640625, 0.3175697326660156, 0.808233916759491, 1.7470312118530273, 1.2061309814453125, -2.629307270050049, 4.101898670196533, -0.7667667269706726, 3.4183855056762695, 1.7702914476394653, 1.5651687383651733, -1.5406545400619507, -1.1265442371368408, -0.5685543417930603, 0.5226432085037231, 0.2861633896827698, 0.39434540271759033, -0.015310361050069332, -2.7481589317321777, 1.8284224271774292, 2.206653118133545, 0.7730680704116821, 1.9381710290908813, -3.284010410308838, -0.7427114248275757, 0.876792848110199, 0.751535177230835, 1.190385103225708, -1.550650954246521, 2.2972371578216553, -1.3535515069961548, 0.12886178493499756, -1.6089788675308228, 0.5237014889717102, -1.0390559434890747, -1.9086157083511353, 0.3069864809513092, 1.4717150926589966, 0.11776185035705566, 0.16988500952720642, 0.12178287655115128, -0.6901646256446838, -2.183614492416382, -2.3509368896484375, 0.29397448897361755, 2.7133145332336426, 0.6542174816131592, -0.4122510850429535, 0.5294830799102783, 1.7905569076538086, -0.536406397819519, 2.5445210933685303, 0.3314356207847595, -1.468543291091919, -3.5287129878997803, -0.8809077143669128, 1.6392606496810913, -0.9842962622642517, 0.3053302466869354, -1.4739573001861572, -2.3423876762390137, -1.1231565475463867, 1.0083675384521484, -0.5808987617492676, 2.353801965713501, -1.1411926746368408, 0.07961893826723099, -2.8334505558013916, -0.3613957464694977, -1.7505133152008057, 0.865211546421051, 2.040654420852661, 1.080287218093872, 1.0086419582366943, 1.7103056907653809, -3.715000867843628, -1.840010643005371, 0.5772089958190918, -3.155902624130249, -5.309390544891357, -0.7934429049491882, 0.9370364546775818, -2.1561107635498047, -1.8011596202850342, 1.898012399673462, 1.8237905502319336, 3.3112032413482666, -0.5970373153686523, -1.178517460823059, -1.820722222328186, 0.3587028384208679, -0.8013581037521362, 1.1024905443191528, 1.426895260810852, 0.9316889643669128, -1.8198521137237549, -1.4190810918807983, -1.7484005689620972, 0.05801962688565254, 0.8294456005096436, -0.6534862518310547, 1.2567672729492188, -0.3195081055164337, 1.6223028898239136, 1.6932445764541626, -0.07647433876991272, 0.47069668769836426, 0.048803821206092834, 3.744521141052246, 1.7789039611816406, 0.5958625078201294, 1.077486515045166, 1.1653867959976196, 0.8769011497497559, 2.327101945877075, 0.24130447208881378, -2.218080520629883, -0.9479566216468811, 1.7761738300323486, 0.7679473757743835, -0.9474920034408569, 0.9137771129608154, -0.3874184489250183, -0.04096802696585655, -0.11778634041547775, 0.8596916794776917, 0.28380247950553894, -2.367616891860962, -1.2395961284637451, -0.3675225079059601, -1.887308955192566, -1.304110050201416, 1.7800384759902954, 0.50917649269104, -3.297497034072876, 0.887869656085968, 0.04554005339741707, -0.21212980151176453, 9.255128860473633, 0.5325005054473877, 0.6580191254615784, 1.409842610359192, 0.9823986887931824, 0.06371606886386871, 0.913949728012085, -1.6375190019607544, 1.795844316482544, -1.2914022207260132, -2.048330068588257, 3.547797918319702, -1.4547251462936401, -2.1789541244506836, -1.0999540090560913, 3.08674955368042, 1.0450226068496704, 1.3998850584030151, 1.272565245628357, -3.4633827209472656, 0.8760677576065063, 0.14305835962295532, -1.1367288827896118, 2.8966472148895264, -0.5341393947601318, 0.8198519349098206, -4.71492338180542, -1.9030556678771973, -0.5913074612617493, 0.3837783932685852, -1.1635862588882446, 3.0315604209899902, -0.8282106518745422, -0.2835896909236908, 0.4073132872581482, -0.6294971704483032, 0.515637993812561, -0.4483289122581482, 1.8397879600524902, 0.08986455947160721, -1.3697509765625, 0.18812866508960724, -1.3013958930969238, 0.7333452105522156, -1.87993323802948, -0.22861552238464355, -0.6001943945884705, 0.5926730036735535, -2.2057385444641113, 1.9103038311004639, -1.5532671213150024, 2.4949514865875244, -1.2609312534332275, 0.039182066917419434, -0.008140934631228447 ...
# Row((31737264902872997, '47PRP', 'POINT(102.635462546067 12.2658021655115)', [3.0988240242004395, -0.8685986995697021, 3.523724317550659, 1.077645182609558, 1.5285096168518066, -0.865116536617279, 0.9640526175498962, 0.1575053483247757, 2.379812002182007, -1.0618854761123657, 1.8474210500717163, -3.3177809715270996, 1.24283766746521, 0.5218920707702637, 0.4343540370464325, 0.4179799556732178, -1.5848090648651123, 2.0836074352264404, 0.7489393353462219, 0.7915880084037781, 1.7137643098831177, -0.09259586781263351, 0.23085547983646393, 0.867746889591217, -0.6740413308143616, 0.6447368264198303, 1.679720401763916, 0.050844039767980576, 1.104878306388855, 4.636991024017334, 1.1845288276672363, -0.6794971227645874, -1.2214045524597168, 2.310546398162842, -2.234779119491577, -1.514090657234192, 0.7007415890693665, -0.566608190536499, -0.967786967754364, 2.219082832336426, -0.23487386107444763, -0.2643616497516632, -0.950985312461853, -0.5474568009376526, 1.8334919214248657, 0.9998874664306641, -0.732150673866272, -1.2675857543945312, -0.8139271140098572, 0.0902477353811264, 1.1780142784118652, 2.400174140930176, -0.735815167427063, 1.0233137607574463, -5.154081344604492, -0.3406085669994354, 1.3953744173049927, -0.9257422685623169, 0.3555755913257599, -0.18820582330226898, -2.909156322479248, 0.5739223957061768, 1.9958945512771606, 1.5414360761642456, 1.1054165363311768, 0.09931689500808716, 1.760233998298645, -1.2738059759140015, 1.1817035675048828, -2.120993137359619, 0.11453843116760254, 1.8437306880950928, 1.5020453929901123, 2.3471226692199707, 2.0126872062683105, -1.3202662467956543, -0.21953219175338745, 0.9859033226966858, -2.5338146686553955, -4.62169885635376, -2.9407224655151367, 2.400930404663086, -1.05746328830719, 0.7613640427589417, 1.0711182355880737, 1.6239594221115112, 1.6096115112304688, -2.649501323699951, -2.3129472732543945, -1.198111891746521, 0.09034885466098785, -1.5959652662277222, 3.6133625507354736, -0.1759900003671646, -0.453904926776886, -0.32090240716934204, 0.5701957941055298, 0.5921573638916016, -1.1254044771194458, -0.08187039941549301, 0.32686078548431396, 0.7903527021408081, 1.1069592237472534, -1.4190824031829834, -0.12902572751045227, -0.7252932786941528, 0.21771425008773804, 0.3905566930770874, 1.9858019351959229, 1.001395344734192, -0.3445405662059784, 2.7390780448913574, 1.713496446609497, -0.6735869646072388, 1.4372663497924805, 1.6437586545944214, -1.7812235355377197, -3.0592586994171143, 2.530207633972168, 0.351879358291626, 2.0972847938537598, 3.850551128387451, 0.5402534604072571, -0.4512113928794861, 0.8311893939971924, 0.9940696358680725, 0.8153853416442871, -2.0353951454162598, -2.6296355724334717, -0.43087950348854065, 1.507164716720581, -1.007859468460083, 3.1795315742492676, -0.741202712059021, -0.7795811295509338, 0.23422381281852722, 0.6851226091384888, -1.4353220462799072, 10.639337539672852, -1.4938520193099976, 2.186889410018921, 0.21163134276866913, -0.6951652765274048, -0.5604667067527771, 1.680678367614746, 0.5154287815093994, 1.536882758140564, 0.8283201456069946, -1.1274340152740479, -0.148399218916893, -2.5542004108428955, -3.1340091228485107, -1.538450002670288, 1.152112364768982, 0.8051209449768066, -0.6036335825920105, -0.6601574420928955, -2.632315158843994, -0.01989126391708851, 0.16878700256347656, 0.9482539892196655, 2.2397351264953613, 2.5346872806549072, -0.48948001861572266, -3.8291614055633545, -2.2023582458496094, -0.7657802104949951, 2.4979774951934814, -2.2328712940216064, 2.382518768310547, -0.8209856748580933, -1.2716341018676758, -0.7308675646781921, -2.9418182373046875, 1.7211354970932007, -3.719132423400879, -1.7026370763778687, -1.720712661743164, -1.9712276458740234, -0.2832193672657013, 1.4237977266311646, -1.743424654006958, -4.177302837371826, -1.5024882555007935, 1.9164197444915771, 2.7689874172210693, -3.4498116970062256, 1.1353622674942017, -0.20033268630504608, 1.0805081129074097, -1.4049670696258545, -0.43315428495407104, -0.7156410217285156, ...
# Row((31737323128679914, '47PRP', 'POINT(102.301501619393 12.4986425628414)', [3.0304033756256104, -1.1830470561981201, 3.4803361892700195, 0.7530701160430908, 1.5113457441329956, -0.8780829906463623, 1.798327922821045, -0.5419204235076904, 3.9872381687164307, 0.21712622046470642, 1.6364927291870117, -3.797299385070801, 0.07363526523113251, 0.7349013090133667, -0.10967494547367096, 1.3327980041503906, -0.9527124166488647, 1.421271800994873, 0.4165300726890564, 0.8952515125274658, 1.3620309829711914, -0.33034345507621765, 0.6107280850410461, 0.854547381401062, -0.42007651925086975, 0.46415817737579346, 1.1184816360473633, -0.7196232080459595, 1.1067379713058472, 4.361123561859131, 0.8013498187065125, -0.6294276118278503, -1.0272603034973145, 2.2744712829589844, -2.593634605407715, -1.5159435272216797, 0.1662794053554535, -1.3812347650527954, -0.5923762321472168, 2.1983370780944824, 0.15789781510829926, -0.03709730878472328, -1.6631985902786255, -0.35102295875549316, 1.41557776927948, 0.9863031506538391, -1.4668909311294556, -1.231520414352417, 0.002771404106169939, -0.11980707198381424, 0.8611670136451721, 2.119959831237793, -0.7728230953216553, 0.23277433216571808, -5.345338344573975, -0.8100820779800415, 1.2433339357376099, -1.3339332342147827, -0.22222302854061127, -0.4014773368835449, -2.6346426010131836, 0.5530836582183838, 2.1550064086914062, 1.4850492477416992, 1.1135451793670654, -0.033381544053554535, 1.751031517982483, -1.4414103031158447, 0.33129939436912537, -1.927362322807312, 0.64130699634552, 1.7841204404830933, 1.7290849685668945, 2.172027826309204, 3.248650074005127, -0.9081078171730042, 0.1400669664144516, 0.9886777400970459, -3.07232403755188, -4.940793991088867, -1.9060211181640625, 1.951448678970337, -0.34393757581710815, 0.09172733873128891, -0.2098136693239212, 1.984257459640503, 1.4165526628494263, -2.1648669242858887, -1.54090416431427, -1.2125794887542725, 0.5615434050559998, -1.9423043727874756, 3.012911558151245, 0.07003635168075562, -1.2900241613388062, -0.1984788030385971, 0.422911673784256, 0.9027486443519592, 0.07266265153884888, 0.11687152087688446, 0.0444125235080719, 1.4055812358856201, 0.7227025032043457, -1.008392333984375, -0.26050570607185364, -0.3033294379711151, -0.14903971552848816, 0.5431098341941833, 1.4536060094833374, 0.5373296141624451, -0.4688829779624939, 1.41112220287323, 1.3150056600570679, 0.36825671792030334, 0.17698101699352264, 1.8207441568374634, -1.045861840248108, -2.7862727642059326, 1.6788311004638672, 0.6725594401359558, 1.3193137645721436, 2.456878185272217, 0.882408618927002, 0.019069980829954147, 1.5835736989974976, 1.3900306224822998, 1.3234291076660156, -2.5242297649383545, -2.112643241882324, -1.1626849174499512, 1.503844141960144, -1.3406351804733276, 2.4326834678649902, -1.605341911315918, -1.3663508892059326, 0.3892967402935028, 1.7022699117660522, -1.7328797578811646, 10.585404396057129, -1.2722084522247314, 1.6508283615112305, 0.764618456363678, -0.460798442363739, -0.24380998313426971, 1.3627573251724243, 0.061463166028261185, 1.7505669593811035, 1.4580507278442383, -1.0398262739181519, 0.2999354302883148, -3.284209966659546, -2.432586908340454, -0.872824490070343, 1.85655677318573, 1.8333489894866943, -0.30326488614082336, -1.5760358572006226, -3.0952396392822266, 0.584239661693573, -0.15744337439537048, 0.7800208926200867, 1.7694300413131714, 1.8053749799728394, -0.4129355549812317, -3.6009628772735596, -2.883979558944702, -0.9942890405654907, 1.0717140436172485, -2.7686829566955566, 2.1535696983337402, -0.7057531476020813, -1.6684399843215942, -1.5358248949050903, -2.599194049835205, 1.259817361831665, -3.8982369899749756, -1.223126769065857, -1.0894908905029297, -1.0726312398910522, 0.47978726029396057, 1.1451705694198608, -1.6090736389160156, -2.97635817527771, -1.6211838722229004, 1.5714983940124512, 2.4603939056396484, -2.7635083198547363, 1.4770910739898682, -0.5572364330291748, 0.8904184103012085, -1.3829785585403442, 0.14539985358715057, -0.630046 ...
# Row((31736781233325110, '47PRP', 'POINT(102.245687333736 11.8978568462742)', [4.737168312072754, 0.21273554861545563, 0.7733211517333984, 1.510983943939209, 1.065757155418396, -2.1911392211914062, 4.073158264160156, -0.9825093746185303, 3.4351227283477783, 1.580511450767517, 1.5882638692855835, -1.452599287033081, -1.1558747291564941, -0.3005303740501404, 0.3618488907814026, 0.23509564995765686, 0.5835920572280884, -0.034017324447631836, -3.0294179916381836, 2.03120756149292, 2.469456672668457, 0.9944853186607361, 1.8238568305969238, -4.1374616622924805, -0.9402575492858887, 0.6374430060386658, 0.38019609451293945, 0.9384469985961914, -1.7071894407272339, 2.4015657901763916, -1.3390309810638428, 0.07389465719461441, -1.7237244844436646, 0.5987549424171448, -0.7223086953163147, -2.074342966079712, 0.10218758136034012, 1.5636849403381348, -0.22348597645759583, 0.20067496597766876, 0.19082435965538025, -0.4708919823169708, -2.179874897003174, -2.325662851333618, 0.5053284764289856, 2.8964710235595703, 0.4395669400691986, -0.26172253489494324, 0.37694424390792847, 1.6556589603424072, -0.1360209882259369, 2.3436014652252197, 0.40136244893074036, -0.9952019453048706, -3.453964948654175, -0.7392640113830566, 1.8742406368255615, -0.8775479793548584, 0.11082383245229721, -1.9689559936523438, -2.4826037883758545, -1.3062270879745483, 1.0354543924331665, -0.3703612685203552, 2.683515787124634, -0.8183969855308533, -0.3258821368217468, -2.824662923812866, -0.23005624115467072, -1.700844168663025, 0.9271453619003296, 2.136345386505127, 1.0397151708602905, 1.141262173652649, 1.6247272491455078, -3.5345866680145264, -2.1739799976348877, 0.7011401057243347, -3.141688585281372, -5.16880989074707, -0.517844557762146, 0.8781391382217407, -2.5749661922454834, -1.8872530460357666, 1.9733383655548096, 2.145280361175537, 3.286360740661621, -0.8363809585571289, -1.2620376348495483, -2.3482329845428467, 0.3772125244140625, -0.8470560908317566, 1.2243492603302002, 1.1357190608978271, 0.8847628831863403, -2.1427080631256104, -1.3358196020126343, -1.4027332067489624, -0.1494850516319275, 0.7217215299606323, -0.4089009761810303, 1.5793819427490234, -0.5038244724273682, 1.5319204330444336, 1.6463242769241333, 0.024543972685933113, 0.6065745949745178, 0.02282400242984295, 3.6644389629364014, 1.7369956970214844, 0.4049759805202484, 1.1624960899353027, 1.1772091388702393, 1.039035439491272, 2.2936484813690186, 0.07323722541332245, -2.26552152633667, -0.717674970626831, 1.7720118761062622, 1.018052101135254, -1.056965708732605, 0.9135629534721375, -0.1648813635110855, -0.2993430197238922, -0.04656749963760376, 0.6766816973686218, 0.29457610845565796, -2.5939533710479736, -0.9814713001251221, -0.34150174260139465, -2.1752610206604004, -1.6381936073303223, 1.9595003128051758, 0.5799681544303894, -3.3119847774505615, 0.9452384114265442, -0.2326613813638687, -0.3074367046356201, 8.946128845214844, 0.35967516899108887, 0.6228266954421997, 1.2101318836212158, 1.4017952680587769, -0.17459562420845032, 0.9288588166236877, -1.0832195281982422, 1.7244311571121216, -0.9978798031806946, -1.8659878969192505, 3.9063546657562256, -1.2034660577774048, -2.186211585998535, -1.2526534795761108, 2.934387445449829, 0.9080451130867004, 1.2372057437896729, 1.284608006477356, -3.620573043823242, 0.8015303015708923, -0.28792035579681396, -1.0121188163757324, 2.891495704650879, -0.3371807336807251, 0.677730143070221, -4.806548118591309, -2.3351316452026367, -0.4878808557987213, 0.2606422007083893, -1.2482047080993652, 2.5760586261749268, -0.7054356336593628, 0.03592974692583084, 0.41642701625823975, -0.3601687550544739, 0.3128872215747833, -0.6639485955238342, 1.935052752494812, 0.19834554195404053, -1.2841423749923706, 0.09457051008939743, -1.3077670335769653, 0.567603588104248, -1.841833233833313, -0.2935542166233063, -0.44756174087524414, 0.5205458402633667, -1.930773377418518, 2.279963493347168, -1.991645336151123, 3.027824878692627, -1.381156325340271, 0.36303550004959106, -0.1810 ...
# Row((31737151698133283, '47PRP', 'POINT(102.30007591279 11.9769075984541)', [4.2049970626831055, 0.498841792345047, 1.217198371887207, 2.0012218952178955, 2.052124261856079, -1.7541253566741943, 3.601522207260132, -0.017405766993761063, 3.6574759483337402, 0.35300958156585693, 1.160641074180603, -2.0289299488067627, 1.2752286195755005, -0.9382632970809937, -1.7712076902389526, 1.3118757009506226, 0.5465846657752991, -0.1010107770562172, -1.63840913772583, 1.863045334815979, 0.7289279699325562, -0.470186322927475, 1.1895787715911865, -1.504677176475525, -0.3195684850215912, 0.10139203816652298, 0.886208176612854, 0.26935145258903503, -0.21510639786720276, 3.7204854488372803, -1.614535927772522, -2.009817123413086, -1.7895541191101074, 1.6098740100860596, -2.1314775943756104, -1.788740873336792, 0.3825947046279907, 0.6173287630081177, 0.004703240469098091, 0.527281641960144, 0.13699445128440857, -0.18445636332035065, -1.3237038850784302, -1.1486492156982422, 0.459519624710083, 2.530529260635376, 0.41019392013549805, -0.07437414675951004, 0.8470099568367004, 1.1990057229995728, -0.5872147083282471, 2.658858299255371, 0.6452701091766357, -2.953761100769043, -3.3688273429870605, -1.339457392692566, 0.93207848072052, -1.3990087509155273, 0.17717041075229645, -0.1924569308757782, -1.979297161102295, -1.0591914653778076, 1.4221243858337402, 0.2728036642074585, 0.7959203124046326, -1.1585637331008911, -0.2274255007505417, -3.142070770263672, 0.3102077543735504, -1.8096641302108765, 0.8718818426132202, 0.9609633088111877, 0.12449309974908829, 0.7448936700820923, 2.7642323970794678, -3.7125539779663086, 0.24541613459587097, 1.7117127180099487, -2.2749335765838623, -5.36922025680542, -0.5297152996063232, 0.964942216873169, -2.054123878479004, -1.0547823905944824, 1.481105923652649, 2.6145269870758057, 3.822348117828369, -1.127261757850647, -2.2621898651123047, -1.6441153287887573, 0.1999199092388153, -1.7167096138000488, 1.925681471824646, 0.32817330956459045, 1.3200500011444092, -0.7366232872009277, -0.693317174911499, -1.4895520210266113, -0.8511687517166138, -0.29415035247802734, -1.2958699464797974, 1.3811111450195312, -0.9021914005279541, -0.04830961301922798, 0.12252227216959, -1.476806640625, 1.3836933374404907, 0.974875271320343, 3.963945150375366, 1.9498258829116821, 0.6596478819847107, 1.6481373310089111, 1.3346155881881714, 0.8142259120941162, 2.3942244052886963, 0.18100103735923767, -1.5957269668579102, -0.11838264018297195, 1.3314367532730103, 0.3959616422653198, -0.5476806163787842, 1.7299590110778809, 0.5855736136436462, -0.05235235393047333, 1.036087989807129, 0.9730660915374756, 0.740056574344635, -1.6477261781692505, -1.577884554862976, -0.13267776370048523, -0.062349833548069, -0.16524675488471985, 0.7615472674369812, -0.06937334686517715, -4.037022113800049, -0.3879891037940979, -0.40330079197883606, -0.545464277267456, 8.528938293457031, 1.033737063407898, 0.34412455558776855, 1.240670919418335, 0.1565859019756317, 0.6563075184822083, -0.2253192663192749, -0.6532691717147827, 1.863892912864685, -1.5314464569091797, -2.3514037132263184, 3.14516282081604, -2.6292245388031006, -2.8075907230377197, -0.33256804943084717, 2.9278993606567383, -0.25978922843933105, 1.60103178024292, 0.9856637120246887, -4.084332466125488, 1.035603642463684, 0.3251165449619293, -0.34078264236450195, 0.9809542894363403, 0.3964594900608063, 0.08974170684814453, -4.8962483406066895, -2.0063893795013428, 0.15413162112236023, -0.8105782866477966, -0.6318395137786865, 2.687950372695923, -0.9597766399383545, -1.1000034809112549, 0.99668949842453, -1.5542267560958862, 0.7275094389915466, 0.31049060821533203, 0.8775601387023926, 0.2520124316215515, -2.868114948272705, 0.8560817241668701, -0.36353638768196106, 1.9932456016540527, -3.404203414916992, -0.3171078562736511, 0.10442766547203064, 0.0023759203031659126, -0.9639196991920471, 2.2183165550231934, -0.39388507604599, 1.1063469648361206, -1.634109377861023, 1.02059006690979, 1.5420572757720947, -1.0 ...
# Row((31736940951333966, '47PRP', 'POINT(101.827353985552 11.9855313168737)', [4.272178649902344, 0.21864302456378937, 0.5853268504142761, 1.3890348672866821, 0.9277034997940063, -2.3198044300079346, 4.118077278137207, -1.0959203243255615, 3.4660086631774902, 1.5799872875213623, 1.7702940702438354, -1.6582374572753906, -1.1895674467086792, -0.3415626585483551, 0.48704856634140015, -0.10034410655498505, 0.4736970067024231, 0.04111505672335625, -3.028693199157715, 1.7935336828231812, 2.335646390914917, 0.8388815522193909, 1.8452643156051636, -3.874180316925049, -0.8597763180732727, 0.9645848870277405, 0.4889688193798065, 1.0077494382858276, -1.9769009351730347, 2.1470654010772705, -1.1995649337768555, 0.08363504707813263, -1.709954023361206, 0.4416224956512451, -0.6699925661087036, -1.8153363466262817, 0.18421389162540436, 1.8658955097198486, -0.1793571412563324, 0.36972776055336, 0.2724095284938812, -0.7212874889373779, -2.147770404815674, -2.256673574447632, 0.5941182374954224, 2.684074640274048, 0.45405861735343933, -0.39965105056762695, 0.5075052380561829, 1.8013207912445068, -0.40041202306747437, 2.2993407249450684, 0.3343052566051483, -1.033604621887207, -3.3551857471466064, -0.7264055609703064, 1.7665597200393677, -0.9449074864387512, 0.3743463456630707, -1.8131710290908813, -2.320563554763794, -1.3235937356948853, 1.085595965385437, -0.3917927145957947, 2.6154091358184814, -0.8422037959098816, 0.10155423730611801, -2.8716466426849365, -0.10313855856657028, -1.8036080598831177, 0.7083377838134766, 2.3750205039978027, 1.0157496929168701, 1.2714340686798096, 1.7351899147033691, -3.4772260189056396, -2.1338343620300293, 0.49381008744239807, -3.1989643573760986, -5.252264022827148, -0.5584255456924438, 0.6911116242408752, -2.229367256164551, -1.8263651132583618, 2.1050140857696533, 1.9837807416915894, 3.2795090675354004, -0.756347119808197, -1.2913320064544678, -1.882408857345581, 0.3714918792247772, -0.7405158877372742, 1.0529817342758179, 1.3635798692703247, 1.0656405687332153, -2.379199504852295, -1.3798786401748657, -1.5596510171890259, -0.1696997731924057, 1.0994635820388794, -0.4751861095428467, 1.1534990072250366, -0.3651616871356964, 1.7743452787399292, 1.9226911067962646, -0.007217021193355322, 0.3696858882904053, 0.13701209425926208, 3.8025615215301514, 1.8283430337905884, 0.5320244431495667, 0.9925040006637573, 1.1975982189178467, 0.8991607427597046, 2.3314452171325684, 0.0017342793289572, -2.302452802658081, -1.09364914894104, 1.8586701154708862, 0.9116352200508118, -0.9670553803443909, 0.8567654490470886, -0.31874415278434753, -0.23550595343112946, -0.14177121222019196, 0.7691898941993713, -0.04782343655824661, -2.4810945987701416, -1.1266345977783203, -0.22325722873210907, -2.2526302337646484, -1.5192030668258667, 2.1025633811950684, 0.7623251080513, -3.5437519550323486, 1.114688754081726, -0.3599250912666321, -0.3424409031867981, 9.428674697875977, 0.6150458455085754, 0.918374240398407, 1.2453696727752686, 1.5807976722717285, -0.04773259907960892, 0.7253972291946411, -1.252402901649475, 1.727584958076477, -1.2616819143295288, -1.7936657667160034, 3.5813543796539307, -1.2580657005310059, -2.213433027267456, -1.3208762407302856, 2.9452192783355713, 0.8258479237556458, 1.146942138671875, 1.284174919128418, -3.5020751953125, 0.6705440878868103, -0.0741606280207634, -1.1840535402297974, 2.6928906440734863, -0.6618036031723022, 0.8401632308959961, -4.830552577972412, -2.0198512077331543, -0.45252108573913574, 0.3308190107345581, -1.1992530822753906, 2.5696845054626465, -0.6625115871429443, -0.12623143196105957, 0.16379056870937347, -0.28220152854919434, 0.3105126619338989, -0.39216896891593933, 1.8140459060668945, 0.10189754515886307, -1.4654556512832642, -0.04667307063937187, -1.3145227432250977, 0.3994506299495697, -2.1108016967773438, -0.29160892963409424, -0.5097143054008484, 0.7074722051620483, -2.1371958255767822, 2.090867042541504, -2.03825306892395, 2.9924023151397705, -1.3999477624893188, 0.5076783895492554,  ...
# Row((31737156448692993, '47PRP', 'POINT(102.15433610975 12.0861413651027)', [4.303479194641113, 0.28800860047340393, 0.7701689600944519, 1.6755893230438232, 1.2275776863098145, -2.2583088874816895, 3.8921239376068115, -0.7491326928138733, 3.5948264598846436, 1.4866139888763428, 1.7788115739822388, -1.5759812593460083, -0.9735020399093628, -0.2698064148426056, 0.16246245801448822, 0.2681684195995331, 0.4698110520839691, 0.02146177366375923, -2.797741413116455, 2.0819547176361084, 2.312227487564087, 0.7194162607192993, 1.609292984008789, -3.4590036869049072, -0.7243425846099854, 0.7374576330184937, 0.7059332728385925, 1.322910189628601, -1.3152960538864136, 2.324842691421509, -1.3795806169509888, -0.32206985354423523, -1.7781591415405273, 0.5152595043182373, -0.9490833282470703, -2.0126888751983643, 0.16634155809879303, 1.3256936073303223, 0.02082911878824234, 0.3385428488254547, 0.23481926321983337, -0.5674147009849548, -2.0287461280822754, -2.146655559539795, 0.1555216759443283, 2.6377651691436768, 0.6150331497192383, -0.5322758555412292, 0.5480665564537048, 1.789139747619629, -0.3715575635433197, 2.506722927093506, 0.43632739782333374, -1.3860018253326416, -3.542480707168579, -0.7778246998786926, 1.8835045099258423, -1.004105806350708, 0.3262317478656769, -1.3593318462371826, -2.4827427864074707, -1.1243442296981812, 1.0794596672058105, -0.5058888792991638, 2.2056257724761963, -1.1603496074676514, 0.0018519324949011207, -2.736013889312744, -0.13221615552902222, -1.8585281372070312, 0.6329363584518433, 1.9488470554351807, 1.064078688621521, 0.8919565677642822, 1.8132193088531494, -3.744669198989868, -1.7510381937026978, 0.6923590898513794, -2.967129707336426, -5.379819869995117, -0.7254200577735901, 0.9027788639068604, -1.9643003940582275, -1.7373225688934326, 1.7995558977127075, 2.2240800857543945, 3.197516679763794, -0.5375059843063354, -1.372672200202942, -2.0091023445129395, 0.2428843379020691, -0.7112691402435303, 0.9695550799369812, 1.4552401304244995, 0.9842426180839539, -1.809654712677002, -1.2796183824539185, -1.6418753862380981, 0.059615928679704666, 0.6780585646629333, -0.5729702711105347, 1.3568063974380493, -0.5343394875526428, 1.5017746686935425, 1.5001033544540405, -0.26767751574516296, 0.40400993824005127, 0.253642737865448, 3.708265542984009, 1.6246495246887207, 0.5072534680366516, 0.8729034066200256, 1.0864791870117188, 0.8367888331413269, 2.4051733016967773, 0.16702300310134888, -2.3245062828063965, -0.6645393967628479, 1.5682971477508545, 0.8457627892494202, -0.885715126991272, 1.1251623630523682, -0.1872015744447708, -0.04279463365674019, 0.22972002625465393, 0.7449183464050293, 0.3806118965148926, -2.4283642768859863, -1.2030586004257202, -0.2900026738643646, -1.7796494960784912, -1.478905200958252, 1.8018174171447754, 0.39320653676986694, -3.538239002227783, 0.9267181754112244, 0.08056855946779251, -0.15288512408733368, 9.161760330200195, 0.3875299394130707, 0.5500659346580505, 1.202716588973999, 1.1483714580535889, 0.04881720244884491, 0.7583437561988831, -1.5757371187210083, 1.56428062915802, -1.05018949508667, -1.971388816833496, 3.5430009365081787, -1.5059146881103516, -2.3791658878326416, -1.0486549139022827, 3.100808620452881, 0.7538309097290039, 1.2754013538360596, 1.540682077407837, -3.526095390319824, 1.0253050327301025, 0.16165153682231903, -0.9569380283355713, 2.5887227058410645, -0.4775506258010864, 0.8783001899719238, -5.01162052154541, -1.7079395055770874, -0.5437421202659607, 0.1990576833486557, -1.1733521223068237, 2.782010078430176, -0.770771861076355, -0.5813016891479492, 0.48468682169914246, -0.5697768926620483, 0.9094966053962708, -0.32520782947540283, 1.816618800163269, 0.04017426446080208, -1.6171644926071167, 0.1415526419878006, -1.2521222829818726, 0.8638206720352173, -2.1477839946746826, -0.2833092510700226, -0.3845040202140808, 0.438764750957489, -2.096889019012451, 1.991353988647461, -1.5432689189910889, 2.546725034713745, -1.1203947067260742, 0.19992148876190186, 0.13612543046 ...
# Row((31737146244465207, '47PRP', 'POINT(102.152949531063 11.9754703120509)', [4.666621685028076, 0.1387614756822586, 1.2440495491027832, 1.5855873823165894, 1.427328109741211, -1.9995626211166382, 4.010337829589844, -0.5367336869239807, 3.4865500926971436, 1.5898991823196411, 1.4865360260009766, -1.7984586954116821, -0.7491379380226135, -0.11464238166809082, -0.003810179652646184, 0.23090603947639465, 0.44034630060195923, 0.05941244587302208, -2.7459020614624023, 1.8722416162490845, 2.157285213470459, 0.5174410939216614, 1.4900274276733398, -3.479139804840088, -1.113432765007019, 0.5496013760566711, 0.42289453744888306, 0.800366222858429, -1.0424710512161255, 2.8009467124938965, -1.4492279291152954, -0.7142772078514099, -2.0387654304504395, 0.6570729613304138, -0.9349968433380127, -1.9258898496627808, -0.03324193134903908, 0.912528395652771, -0.008141107857227325, 0.4655474126338959, 0.08758247643709183, -0.4028777480125427, -1.8065351247787476, -2.2190816402435303, 0.46501433849334717, 2.807706117630005, 0.4675518572330475, -0.5290951132774353, 0.414090633392334, 1.697011947631836, -0.10036609321832657, 2.526500940322876, 0.25484994053840637, -1.3193718194961548, -3.741476535797119, -0.7112059593200684, 1.8559285402297974, -1.0626786947250366, -0.07424891740083694, -1.6104670763015747, -2.3561313152313232, -1.2932562828063965, 1.2800170183181763, -0.33659541606903076, 2.368088960647583, -0.8744115233421326, -0.12898486852645874, -2.919708251953125, -0.20987431704998016, -1.6917048692703247, 0.7421092987060547, 1.8144234418869019, 1.0599793195724487, 1.0537070035934448, 1.7850828170776367, -3.4826269149780273, -1.7132172584533691, 0.7819100618362427, -2.6239123344421387, -5.314033031463623, -0.5990889072418213, 0.9882056713104248, -2.4961609840393066, -1.724888563156128, 1.703857183456421, 2.5168299674987793, 3.3252811431884766, -0.7256678938865662, -1.4125311374664307, -2.4547414779663086, 0.28330788016319275, -1.0864824056625366, 1.3959801197052002, 1.024461269378662, 0.8044857382774353, -1.7147284746170044, -1.0397958755493164, -1.610975980758667, -0.17585761845111847, 0.4912809729576111, -0.43839868903160095, 1.6983745098114014, -0.6711419820785522, 1.2952061891555786, 1.3444221019744873, -0.36527135968208313, 0.750471293926239, 0.16971755027770996, 3.530867576599121, 1.537574291229248, 0.3240602910518646, 0.8648672103881836, 1.146331787109375, 0.9860355854034424, 2.1765120029449463, 0.17920446395874023, -2.1087703704833984, -0.5545471906661987, 1.6223169565200806, 1.0911283493041992, -0.9559067487716675, 1.1239023208618164, 0.07766973227262497, -0.2538481056690216, 0.3396223485469818, 0.9971507787704468, 0.721527099609375, -2.4501354694366455, -0.9672235250473022, -0.36694881319999695, -1.2296961545944214, -1.6080771684646606, 1.7660284042358398, 0.16390863060951233, -3.324812650680542, 0.37938323616981506, 0.0204835906624794, -0.3230419456958771, 9.048223495483398, 0.3709799349308014, 0.6777111291885376, 0.9514940977096558, 0.9051356315612793, 0.03235103189945221, 0.8491683006286621, -1.103885531425476, 1.6102246046066284, -0.7304585576057434, -2.017782688140869, 3.8753342628479004, -1.2617566585540771, -2.3532559871673584, -0.7045339941978455, 3.2016749382019043, 0.8526106476783752, 1.0884546041488647, 1.1607962846755981, -3.426262378692627, 0.8283411860466003, -0.12285701185464859, -0.8281850218772888, 2.745622396469116, -0.32456034421920776, 0.7248033881187439, -4.906411170959473, -2.181563377380371, -0.48892128467559814, 0.17062020301818848, -1.2767077684402466, 2.8023290634155273, -0.8671702742576599, -0.2721051275730133, 0.39812684059143066, -0.4906664788722992, 0.5546255111694336, -0.60865718126297, 1.7930852174758911, 0.21225759387016296, -1.3932485580444336, 0.37991395592689514, -1.363630771636963, 0.8079476356506348, -2.109130620956421, -0.1359052062034607, -0.26463326811790466, 0.4105202853679657, -2.0993540287017822, 2.4589130878448486, -1.7148675918579102, 2.551297426223755, -1.5204801559448242, 0.3493096232 ...

# %% [markdown]
# ### Index BQ table to enable Vector Search

# %%
# test VECTOR SEARCH operations
in_table = '.'.join(result_table.split(".")[1:])
print(f'indexing {in_table} for vector search')
query = f"""
CREATE VECTOR INDEX my_index ON {in_table}(embedding)
OPTIONS(distance_type='COSINE', index_type='IVF', ivf_options='{{"num_lists": 1000}}');
"""

# Run the query to create the index
client = bigquery.Client(project=PROJECT_ID)
job = client.query(query)
job.result()  # Wait for the job to complete
# Out:
# indexing embeddings_sea.earthgenome_cambodia_v1 for vector search

# %% [markdown]
# Create a test target table of 1 record to perform vector search with

# %%
result_table = result_table+"_test_target"
query = f"SELECT * FROM {in_table} LIMIT 1"

job_config = bigquery.QueryJobConfig(destination=result_table)
job = client.query(query,job_config=job_config)
job.result()  # Wait for the job to complete

# %% [markdown]
# Run a Vector Search!

# %%
import datetime
target_table = '.'.join(result_table.split(".")[1:])
print(target_table)
query = f"""
SELECT query.id AS target_id,
  query.tile AS target_tile,
  base.id AS base_id,
  base.tile AS base_tile,
  distance
FROM
  VECTOR_SEARCH(
    TABLE {in_table},
    'embedding',
    TABLE {target_table},
    top_k => 11,
    distance_type => 'COSINE',
    options => '{{"fraction_lists_to_search": 0.005}}')
ORDER BY distance
LIMIT 10
OFFSET 1;
"""

# Run the query to create the index
client = bigquery.Client(project=PROJECT_ID)
search_result_table = f"{PROJECT_ID}.{DATASET_ID}.vector_search_results_{datetime.datetime.now().strftime('%Y%m%d_%H%M%S')}"
job_config = bigquery.QueryJobConfig(destination=search_result_table)
job = client.query(query,job_config=job_config)
job.result()  # Wait for the job to complete
# Out:
# embeddings_sea.earthgenome_cambodia_v1_test_target

# %%
query = f"SELECT * FROM `{search_result_table}` LIMIT 10"
query_job = client.query(query)
# print schema
schema = query_job.result().schema
for field in schema:
    print(f"{field.name}: {field.field_type}")
for row in query_job:
    print(row)
# Out:
# target_id: INTEGER
# target_tile: STRING
# base_id: INTEGER
# base_tile: STRING
# distance: FLOAT
# Row((31737298129880965, '47PRP', 31737295412923663, '47PRP', 0.018239032724844506), {'target_id': 0, 'target_tile': 1, 'base_id': 2, 'base_tile': 3, 'distance': 4})
# Row((31737298129880965, '47PRP', 31737318005760655, '47PRP', 0.018310001948530275), {'target_id': 0, 'target_tile': 1, 'base_id': 2, 'base_tile': 3, 'distance': 4})
# Row((31737298129880965, '47PRP', 31737318187192539, '47PRP', 0.018820251294408008), {'target_id': 0, 'target_tile': 1, 'base_id': 2, 'base_tile': 3, 'distance': 4})
# Row((31737298129880965, '47PRP', 31738782341388707, '47PRQ', 0.019642342550201808), {'target_id': 0, 'target_tile': 1, 'base_id': 2, 'base_tile': 3, 'distance': 4})
# Row((31737298129880965, '47PRP', 31738794989829102, '47PRQ', 0.019749958040534477), {'target_id': 0, 'target_tile': 1, 'base_id': 2, 'base_tile': 3, 'distance': 4})
# Row((31737298129880965, '47PRP', 31737295417137182, '47PRP', 0.020084470457225834), {'target_id': 0, 'target_tile': 1, 'base_id': 2, 'base_tile': 3, 'distance': 4})
# Row((31737298129880965, '47PRP', 31737295403582734, '47PRP', 0.02016205156754791), {'target_id': 0, 'target_tile': 1, 'base_id': 2, 'base_tile': 3, 'distance': 4})
# Row((31737298129880965, '47PRP', 31737326757985998, '47PRP', 0.020228311664431065), {'target_id': 0, 'target_tile': 1, 'base_id': 2, 'base_tile': 3, 'distance': 4})
# Row((31737298129880965, '47PRP', 31737298134094484, '47PRP', 0.020500108388070037), {'target_id': 0, 'target_tile': 1, 'base_id': 2, 'base_tile': 3, 'distance': 4})
# Row((31737298129880965, '47PRP', 31737298116181187, '47PRP', 0.02066469858743014), {'target_id': 0, 'target_tile': 1, 'base_id': 2, 'base_tile': 3, 'distance': 4})
