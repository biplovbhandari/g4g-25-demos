# %%
import ee
print(ee.__version__)
import geemap
from pprint import pprint 
from google.cloud.bigquery import Client

project = "g4g-eaas"
# Set the credentials and project
ee.Initialize(project=project,
                  opt_url="https://earthengine-highvolume.googleapis.com"
              )
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# 1.5.14

# %%
# load Google EFM embedding image over EG data coverage
efm = ee.ImageCollection("GOOGLE/SATELLITE_EMBEDDING/V1/ANNUAL")
efm = efm.filterDate('2024-01-01', '2024-12-31') # EG embeddings are from 2024 so we match with EFM
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %% [markdown]
# load in the intermediate tile-wise EG point-to-patch FeatureCollections, we'll process EFM to patches one tile at a time.

# %%
import subprocess
asset_root = "projects/g4g-eaas/assets/intmd/"
tile_fcs = subprocess.run(f"earthengine ls {asset_root}", shell=True, capture_output=True, text=True).stdout.split("\n")
tile_fcs = [x for x in tile_fcs if x.startswith(asset_root)] # remove empty strings from the list
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
# lets look at one of the tile feature collections
tile_fc = ee.FeatureCollection("projects/g4g-eaas/assets/intmd/eg_pt_to_patch_fc_tile_48PVS")
m = geemap.Map(basemap='HYBRID', 
              center=[12.5, 102.1], 
              zoom=6)
m.addLayer(tile_fc,{}, tile_fcs[0].split("/")[-1],True,0.5)
m.addLayer(efm, {}, 'EFM Embeddings', True, 0.5)
m
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# Map(center=[12.5, 102.1], controls=(WidgetControl(options=['position', 'transparent_bg'], widget=SearchDataGUI…

# %% [markdown]
# Set up some automation

# %%
# want precision with chunking my exports
# so instead of doing fc.size().getInfo() for every intermeiate FC, 
# i'm borrwing from step1 NB to reference original EG embeddings BQ table for tile-wise row counts
PROJECT_ID = "g4g-eaas"
DATASET_ID = "embeddings_sea"
TABLE_ID = "earthgenome_cambodia_v1"
query = f"""
SELECT 
    tile, 
    COUNT(*) AS row_count
FROM 
    `{PROJECT_ID}.{DATASET_ID}.{TABLE_ID}`
GROUP BY 
    tile
ORDER BY 
    row_count DESC
"""
client = Client(project=PROJECT_ID)
query_job = client.query(query)
records_tile = {}
for row in query_job:
    # print(row)
    records_tile[row['tile']] = row['row_count']
print(f"Total tiles in BQ table: {len(records_tile)}")
print("record count by tile:")
pprint(records_tile)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# Total tiles in BQ table: 36
# record count by tile:
# {'47PRP': 234973,
#  '47PRQ': 234942,
#  '47PRR': 234927,
#  '48PTA': 235319,
#  '48PTR': 235437,
#  '48PTS': 235396,
#  '48PTT': 235393,
#  '48PTU': 235383,
#  '48PTV': 235335,
#  '48PUA': 235520,
#  '48PUB': 235520,
#  '48PUS': 235644,
#  '48PUT': 235638,
#  '48PUU': 235624,
#  '48PUV': 235520,
#  '48PVA': 235698,
#  '48PVB': 235674,
#  '48PVS': 235758,
#  '48PVT': 235748,
#  '48PVU': 235720,
#  '48PVV': 235709,
#  '48PWA': 235708,
#  '48PWS': 235737,
#  '48PWT': 235712,
#  '48PWU': 235727,
#  '48PWV': 235699,
#  '48PXA': 235520,
#  '48PXB': 235516,
#  '48PXS': 235606,
#  '48PXT': 235520,
#  '48PXU': 235520,
#  '48PXV': 235520,
#  '48PYA': 235296,
#  '48PYB': 235267,
#  '48PYU': 235331,
#  '48PYV': 235318}

# %% [markdown]
# A few processing functions defined up front

# %%
# Aggregate EFM embedding imagery to each EarthGenome embedding patch location)
def reduce_nested(img, 
                   fc, 
                   reducer:ee.Reducer,
                   scale:int, 
                   crs:str, 
                   crs_transform:ee.List,
                   best_effort:bool, 
                   maxPixels:int, 
                   tileScale:int
                   ):
    def reduce(f):
        reduced = img.reduceRegion(reducer, 
                               f.geometry(), 
                               scale, 
                               crs, 
                               crs_transform, 
                               best_effort, 
                               maxPixels, 
                               tileScale
                               )	
        return f.set(reduced)
    all_reduced = fc.map(reduce)
    return all_reduced
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
# convert band-wise embedding properties returned from reduceRegion() to one embedding array property of type list[float]
def embedding_array_prop(feature):
    # Get all property names
    property_names = feature.propertyNames()
    
    # Filter property names starting with "A"
    matching_properties = property_names.filter(ee.Filter.stringStartsWith('item', 'A'))
    
    # Get the values of the matching properties
    matching_values = matching_properties.map(lambda prop: feature.get(prop))
    
    # Add a new property with the list of matching values
    return feature.set('embedding', matching_values)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
# first gotcha: can't export 'embedding' property as list[float]... 
# so took the suggestion in the export error to encode it to a JSON string.. we'll convert it back in BQ
def convert_embedding_to_string(feature):
    embedding = feature.get('embedding')
    # Convert the list to a string
    embedding_str = ee.String.encodeJSON(embedding)
    return feature.set('embedding', embedding_str)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %% [markdown]
# #### for each EG tile (intermediate feature collection where we've converted Point geom to 320x320m Polygon geom):
# * do some processing to return EFM average embedding for each patch
# * export resulting FC to BQ in chunks

# %%
import math
chunk_size = 5000 # approximate record chunk per BQ export

asset_pattern = "projects/g4g-eaas/assets/intmd/eg_pt_to_patch_fc_tile_"

for i,tile in enumerate(records_tile.keys()):
    if tile in ["48PWS", "48PVB", "48PXS", "48PUB", "48PTR", "48PTS", "48PYB", "47PRP"]:
        continue
    print(i)
    print(f"Processing tile: {tile}")
    record_count = records_tile[tile]
    chunks = math.ceil(record_count / chunk_size)
    step = math.ceil(records_tile[tile] / chunks)
    print(f"record count: {record_count}, chunks: {chunks}, step:{step}")
    tile_fc_path = f"{asset_pattern}{tile}"
    print(tile_fc_path)

    tile_fc = ee.FeatureCollection(tile_fc_path)
    
    # average EFM to eg patches
    efm_patch_embed = reduce_nested(efm.mosaic(),
                           tile_fc,
                           reducer=ee.Reducer.mean(),
                           scale=10,
                           crs='EPSG:4326',
                           crs_transform=None,
                           best_effort=True,
                           maxPixels=1e13,
                           tileScale=16
                          )
    # print("\nresult after reduceRegion:")
    # pprint(efm_patch_embed.first().getInfo()['properties'])

    # convert the band-wise embedding properties to a single embedding array property
    updated_fc = efm_patch_embed.map(embedding_array_prop)
    # print("\nresult after converting band-wise properties to one embedding property:")
    # pprint(updated_fc.first().getInfo())

    # convert embedding property to JSON string for export
    updated_fc = updated_fc.map(convert_embedding_to_string)
    select_fc = updated_fc.select(['id','tile', 'embedding'])
    # print("\nresult after converting embedding to string:")
    # pprint(updated_fc.first().getInfo())
    
    # begin chunking out records for BQ export
    tile_list_allSteps = select_fc.toList(record_count)
    tile_list_noSelect = updated_fc.toList(record_count)
    tile_list_noPP = efm_patch_embed.toList(record_count)


    for i in range(chunks):
        if i < 5:
            continue
        start = i * step
        end = (i + 1) * step
        
        print(f"Exporting records {start} to {end}")
        
        record_chunk_allSteps = ee.FeatureCollection(ee.List(tile_list_allSteps).slice(i*step, (i+1)*step))
        record_chunk_noSelect = ee.FeatureCollection(ee.List(tile_list_noSelect).slice(i*step, (i+1)*step))
        record_chunk_noPP = ee.FeatureCollection(ee.List(tile_list_noPP).slice(i*step, (i+1)*step))

        # taskBQ = ee.batch.Export.table.toBigQuery(
        #     collection=record_chunk_allSteps,
        #     description=f"earthgenome_efm_patch_{tile}_chunked_{start}_{end}_BQ_testAllSteps",
        #     table='g4g-eaas.embeddings_sea.google_efm_cambodia_testAllSteps',
        #     append=True,
        # )
        # taskBQ.start()
        
        # taskBQ2 = ee.batch.Export.table.toBigQuery(
        #     collection=record_chunk_noSelect,
        #     description=f"earthgenome_efm_patch_{tile}_chunked_{start}_{end}_BQ_testNoSelect",
        #     table='g4g-eaas.embeddings_sea.google_efm_cambodia_testNoSelect',
        #     append=True,
        # )
        # taskBQ2.start()
        
        taskBQ3 = ee.batch.Export.table.toBigQuery(
            collection=record_chunk_noPP,
            description=f"earthgenome_efm_patch_{tile}_chunked_{start}_{end}_BQ_testNoPostProcess",
            table='g4g-eaas.embeddings_sea.google_efm_cambodia_testNoPostProcess',
            append=True,
        )
        taskBQ3.start()

        
    
    # break
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# 0
# Processing tile: 48PVS
# record count: 235758, chunks: 48, step:4912
# projects/g4g-eaas/assets/intmd/eg_pt_to_patch_fc_tile_48PVS
# Exporting records 24560 to 29472
# Exporting records 29472 to 34384
# Exporting records 34384 to 39296
# Exporting records 39296 to 44208
# Exporting records 44208 to 49120
# Exporting records 49120 to 54032
# Exporting records 54032 to 58944
# Exporting records 58944 to 63856
# Exporting records 63856 to 68768
# Exporting records 68768 to 73680
# Exporting records 73680 to 78592
# Exporting records 78592 to 83504
# Exporting records 83504 to 88416
# Exporting records 88416 to 93328
# Exporting records 93328 to 98240
# Exporting records 98240 to 103152
# Exporting records 103152 to 108064
# Exporting records 108064 to 112976
# Exporting records 112976 to 117888
# Exporting records 117888 to 122800
# Exporting records 122800 to 127712
# Exporting records 127712 to 132624
# Exporting records 132624 to 137536
# Exporting records 137536 to 142448
# Exporting records 142448 to 147360
# Exporting records 147360 to 152272
# Exporting records 152272 to 157184
# Exporting records 157184 to 162096
# Exporting records 162096 to 167008
# Exporting records 167008 to 171920
# Exporting records 171920 to 176832
# Exporting records 176832 to 181744
# Exporting records 181744 to 186656
# Exporting records 186656 to 191568
# Exporting records 191568 to 196480
# Exporting records 196480 to 201392
# Exporting records 201392 to 206304
# Exporting records 206304 to 211216
# Exporting records 211216 to 216128
# Exporting records 216128 to 221040
# Exporting records 221040 to 225952
# Exporting records 225952 to 230864
# Exporting records 230864 to 235776
# 1
# Processing tile: 48PVT
# record count: 235748, chunks: 48, step:4912
# projects/g4g-eaas/assets/intmd/eg_pt_to_patch_fc_tile_48PVT
# Exporting records 24560 to 29472
# Exporting records 29472 to 34384
# Exporting records 34384 to 39296
# Exporting records 39296 to 44208
# Exporting records 44208 to 49120
# Exporting records 49120 to 54032
# Exporting records 54032 to 58944
# Exporting records 58944 to 63856
# Exporting records 63856 to 68768
# Exporting records 68768 to 73680
# Exporting records 73680 to 78592
# Exporting records 78592 to 83504
# Exporting records 83504 to 88416
# Exporting records 88416 to 93328
# Exporting records 93328 to 98240
# Exporting records 98240 to 103152
# Exporting records 103152 to 108064
# Exporting records 108064 to 112976
# Exporting records 112976 to 117888
# Exporting records 117888 to 122800
# Exporting records 122800 to 127712
# Exporting records 127712 to 132624
# Exporting records 132624 to 137536
# Exporting records 137536 to 142448
# Exporting records 142448 to 147360
# Exporting records 147360 to 152272
# Exporting records 152272 to 157184
# Exporting records 157184 to 162096
# Exporting records 162096 to 167008
# Exporting records 167008 to 171920
# Exporting records 171920 to 176832
# Exporting records 176832 to 181744
# Exporting records 181744 to 186656
# Exporting records 186656 to 191568
# Exporting records 191568 to 196480
# Exporting records 196480 to 201392
# Exporting records 201392 to 206304
# Exporting records 206304 to 211216
# Exporting records 211216 to 216128
# Exporting records 216128 to 221040
# Exporting records 221040 to 225952
# Exporting records 225952 to 230864
# Exporting records 230864 to 235776
# 3
# Processing tile: 48PWU
# record count: 235727, chunks: 48, step:4911
# projects/g4g-eaas/assets/intmd/eg_pt_to_patch_fc_tile_48PWU
# Exporting records 24555 to 29466
# Exporting records 29466 to 34377
# Exporting records 34377 to 39288
# Exporting records 39288 to 44199
# Exporting records 44199 to 49110
# Exporting records 49110 to 54021
# Exporting records 54021 to 58932
# Exporting records 58932 to 63843
# Exporting records 63843 to 68754
# Exporting records 68754 to 73665
# Exporting records 73665 to 78576
# Exporting records 78576 to 83487
# Exporting records 83487 to 88398
# Exporting records 88398 to 93309
# Exporting records 93309 to 98220
# Exporting records 98220 to 103131
# Exporting records 103131 to 108042
# Exporting records 108042 to 112953
# Exporting records 112953 to 117864
# Exporting records 117864 to 122775
# Exporting records 122775 to 127686
# Exporting records 127686 to 132597
# Exporting records 132597 to 137508
# Exporting records 137508 to 142419
# Exporting records 142419 to 147330
# Exporting records 147330 to 152241
# Exporting records 152241 to 157152
# Exporting records 157152 to 162063
# Exporting records 162063 to 166974
# Exporting records 166974 to 171885
# Exporting records 171885 to 176796
# Exporting records 176796 to 181707
# Exporting records 181707 to 186618
# Exporting records 186618 to 191529
# Exporting records 191529 to 196440
# Exporting records 196440 to 201351
# Exporting records 201351 to 206262
# Exporting records 206262 to 211173
# Exporting records 211173 to 216084
# Exporting records 216084 to 220995
# Exporting records 220995 to 225906
# Exporting records 225906 to 230817
# Exporting records 230817 to 235728
# 4
# Processing tile: 48PVU
# record count: 235720, chunks: 48, step:4911
# projects/g4g-eaas/assets/intmd/eg_pt_to_patch_fc_tile_48PVU
# Exporting records 24555 to 29466
# Exporting records 29466 to 34377
# Exporting records 34377 to 39288
# Exporting records 39288 to 44199
# Exporting records 44199 to 49110
# Exporting records 49110 to 54021
# Exporting records 54021 to 58932
# Exporting records 58932 to 63843
# Exporting records 63843 to 68754
# Exporting records 68754 to 73665
# Exporting records 73665 to 78576
# Exporting records 78576 to 83487
# Exporting records 83487 to 88398
# Exporting records 88398 to 93309
# Exporting records 93309 to 98220
# Exporting records 98220 to 103131
# Exporting records 103131 to 108042
# Exporting records 108042 to 112953
# Exporting records 112953 to 117864
# Exporting records 117864 to 122775
# Exporting records 122775 to 127686
# Exporting records 127686 to 132597
# Exporting records 132597 to 137508
# Exporting records 137508 to 142419
# Exporting records 142419 to 147330
# Exporting records 147330 to 152241
# Exporting records 152241 to 157152
# Exporting records 157152 to 162063
# Exporting records 162063 to 166974
# Exporting records 166974 to 171885
# Exporting records 171885 to 176796
# Exporting records 176796 to 181707
# Exporting records 181707 to 186618
# Exporting records 186618 to 191529
# Exporting records 191529 to 196440
# Exporting records 196440 to 201351
# Exporting records 201351 to 206262
# Exporting records 206262 to 211173
# Exporting records 211173 to 216084
# Exporting records 216084 to 220995
# Exporting records 220995 to 225906
# Exporting records 225906 to 230817
# Exporting records 230817 to 235728
# 5
# Processing tile: 48PWT
# record count: 235712, chunks: 48, step:4911
# projects/g4g-eaas/assets/intmd/eg_pt_to_patch_fc_tile_48PWT
# Exporting records 24555 to 29466
# Exporting records 29466 to 34377
# Exporting records 34377 to 39288
# Exporting records 39288 to 44199
# Exporting records 44199 to 49110
# Exporting records 49110 to 54021
# Exporting records 54021 to 58932
# Exporting records 58932 to 63843
# Exporting records 63843 to 68754
# Exporting records 68754 to 73665
# Exporting records 73665 to 78576
# Exporting records 78576 to 83487
# Exporting records 83487 to 88398
# Exporting records 88398 to 93309
# Exporting records 93309 to 98220
# Exporting records 98220 to 103131
# Exporting records 103131 to 108042
# Exporting records 108042 to 112953
# Exporting records 112953 to 117864
# Exporting records 117864 to 122775
# Exporting records 122775 to 127686
# Exporting records 127686 to 132597
# Exporting records 132597 to 137508
# Exporting records 137508 to 142419
# Exporting records 142419 to 147330
# Exporting records 147330 to 152241
# Exporting records 152241 to 157152
# Exporting records 157152 to 162063
# Exporting records 162063 to 166974
# Exporting records 166974 to 171885
# Exporting records 171885 to 176796
# Exporting records 176796 to 181707
# Exporting records 181707 to 186618
# Exporting records 186618 to 191529
# Exporting records 191529 to 196440
# Exporting records 196440 to 201351
# Exporting records 201351 to 206262
# Exporting records 206262 to 211173
# Exporting records 211173 to 216084
# Exporting records 216084 to 220995
# Exporting records 220995 to 225906
# Exporting records 225906 to 230817
# Exporting records 230817 to 235728
# 6
# Processing tile: 48PVV
# record count: 235709, chunks: 48, step:4911
# projects/g4g-eaas/assets/intmd/eg_pt_to_patch_fc_tile_48PVV
# Exporting records 24555 to 29466
# Exporting records 29466 to 34377
# Exporting records 34377 to 39288
# Exporting records 39288 to 44199
# Exporting records 44199 to 49110
# Exporting records 49110 to 54021
# Exporting records 54021 to 58932
# Exporting records 58932 to 63843
# Exporting records 63843 to 68754
# Exporting records 68754 to 73665
# Exporting records 73665 to 78576
# Exporting records 78576 to 83487
# Exporting records 83487 to 88398
# Exporting records 88398 to 93309
# Exporting records 93309 to 98220
# Exporting records 98220 to 103131
# Exporting records 103131 to 108042
# Exporting records 108042 to 112953
# Exporting records 112953 to 117864
# Exporting records 117864 to 122775
# Exporting records 122775 to 127686
# Exporting records 127686 to 132597
# Exporting records 132597 to 137508
# Exporting records 137508 to 142419
# Exporting records 142419 to 147330
# Exporting records 147330 to 152241
# Exporting records 152241 to 157152
# Exporting records 157152 to 162063
# Exporting records 162063 to 166974
# Exporting records 166974 to 171885
# Exporting records 171885 to 176796
# Exporting records 176796 to 181707
# Exporting records 181707 to 186618
# Exporting records 186618 to 191529
# Exporting records 191529 to 196440
# Exporting records 196440 to 201351
# Exporting records 201351 to 206262
# Exporting records 206262 to 211173
# Exporting records 211173 to 216084
# Exporting records 216084 to 220995
# Exporting records 220995 to 225906
# Exporting records 225906 to 230817
# Exporting records 230817 to 235728
# 7
# Processing tile: 48PWA
# record count: 235708, chunks: 48, step:4911
# projects/g4g-eaas/assets/intmd/eg_pt_to_patch_fc_tile_48PWA
# Exporting records 24555 to 29466
# Exporting records 29466 to 34377
# Exporting records 34377 to 39288
# Exporting records 39288 to 44199
# Exporting records 44199 to 49110
# Exporting records 49110 to 54021
# Exporting records 54021 to 58932
# Exporting records 58932 to 63843
# Exporting records 63843 to 68754
# Exporting records 68754 to 73665
# Exporting records 73665 to 78576
# Exporting records 78576 to 83487
# Exporting records 83487 to 88398
# Exporting records 88398 to 93309
# Exporting records 93309 to 98220
# Exporting records 98220 to 103131
# Exporting records 103131 to 108042
# Exporting records 108042 to 112953
# Exporting records 112953 to 117864
# Exporting records 117864 to 122775
# Exporting records 122775 to 127686
# Exporting records 127686 to 132597
# Exporting records 132597 to 137508
# Exporting records 137508 to 142419
# Exporting records 142419 to 147330
# Exporting records 147330 to 152241
# Exporting records 152241 to 157152
# Exporting records 157152 to 162063
# Exporting records 162063 to 166974
# Exporting records 166974 to 171885
# Exporting records 171885 to 176796
# Exporting records 176796 to 181707
# Exporting records 181707 to 186618
# Exporting records 186618 to 191529
# Exporting records 191529 to 196440
# Exporting records 196440 to 201351
# Exporting records 201351 to 206262
# Exporting records 206262 to 211173
# Exporting records 211173 to 216084
# Exporting records 216084 to 220995
# Exporting records 220995 to 225906
# Exporting records 225906 to 230817
# Exporting records 230817 to 235728
# 8
# Processing tile: 48PWV
# record count: 235699, chunks: 48, step:4911
# projects/g4g-eaas/assets/intmd/eg_pt_to_patch_fc_tile_48PWV
# Exporting records 24555 to 29466
# Exporting records 29466 to 34377
# Exporting records 34377 to 39288
# Exporting records 39288 to 44199
# Exporting records 44199 to 49110
# Exporting records 49110 to 54021
# Exporting records 54021 to 58932
# Exporting records 58932 to 63843
# Exporting records 63843 to 68754
# Exporting records 68754 to 73665
# Exporting records 73665 to 78576
# Exporting records 78576 to 83487
# Exporting records 83487 to 88398
# Exporting records 88398 to 93309
# Exporting records 93309 to 98220
# Exporting records 98220 to 103131
# Exporting records 103131 to 108042
# Exporting records 108042 to 112953
# Exporting records 112953 to 117864
# Exporting records 117864 to 122775
# Exporting records 122775 to 127686
# Exporting records 127686 to 132597
# Exporting records 132597 to 137508
# Exporting records 137508 to 142419
# Exporting records 142419 to 147330
# Exporting records 147330 to 152241
# Exporting records 152241 to 157152
# Exporting records 157152 to 162063
# Exporting records 162063 to 166974
# Exporting records 166974 to 171885
# Exporting records 171885 to 176796
# Exporting records 176796 to 181707
# Exporting records 181707 to 186618
# Exporting records 186618 to 191529
# Exporting records 191529 to 196440
# Exporting records 196440 to 201351
# Exporting records 201351 to 206262
# Exporting records 206262 to 211173
# Exporting records 211173 to 216084
# Exporting records 216084 to 220995
# Exporting records 220995 to 225906
# Exporting records 225906 to 230817
# Exporting records 230817 to 235728
# 9
# Processing tile: 48PVA
# record count: 235698, chunks: 48, step:4911
# projects/g4g-eaas/assets/intmd/eg_pt_to_patch_fc_tile_48PVA
# Exporting records 24555 to 29466
# Exporting records 29466 to 34377
# Exporting records 34377 to 39288
# Exporting records 39288 to 44199
# Exporting records 44199 to 49110
# Exporting records 49110 to 54021
# Exporting records 54021 to 58932
# Exporting records 58932 to 63843
# Exporting records 63843 to 68754
# Exporting records 68754 to 73665
# Exporting records 73665 to 78576
# Exporting records 78576 to 83487
# Exporting records 83487 to 88398
# Exporting records 88398 to 93309
# Exporting records 93309 to 98220
# Exporting records 98220 to 103131
# Exporting records 103131 to 108042
# Exporting records 108042 to 112953
# Exporting records 112953 to 117864
# Exporting records 117864 to 122775
# Exporting records 122775 to 127686
# Exporting records 127686 to 132597
# Exporting records 132597 to 137508
# Exporting records 137508 to 142419
# Exporting records 142419 to 147330
# Exporting records 147330 to 152241
# Exporting records 152241 to 157152
# Exporting records 157152 to 162063
# Exporting records 162063 to 166974
# Exporting records 166974 to 171885
# Exporting records 171885 to 176796
# Exporting records 176796 to 181707
# Exporting records 181707 to 186618
# Exporting records 186618 to 191529
# Exporting records 191529 to 196440
# Exporting records 196440 to 201351
# Exporting records 201351 to 206262
# Exporting records 206262 to 211173
# Exporting records 211173 to 216084
# Exporting records 216084 to 220995
# Exporting records 220995 to 225906
# Exporting records 225906 to 230817
# Exporting records 230817 to 235728
# 11
# Processing tile: 48PUS
# record count: 235644, chunks: 48, step:4910
# projects/g4g-eaas/assets/intmd/eg_pt_to_patch_fc_tile_48PUS
# Exporting records 24550 to 29460
# Exporting records 29460 to 34370
# Exporting records 34370 to 39280
# Exporting records 39280 to 44190
# Exporting records 44190 to 49100
# Exporting records 49100 to 54010
# Exporting records 54010 to 58920
# Exporting records 58920 to 63830
# Exporting records 63830 to 68740
# Exporting records 68740 to 73650
# Exporting records 73650 to 78560
# Exporting records 78560 to 83470
# Exporting records 83470 to 88380
# Exporting records 88380 to 93290
# Exporting records 93290 to 98200
# Exporting records 98200 to 103110
# Exporting records 103110 to 108020
# Exporting records 108020 to 112930
# Exporting records 112930 to 117840
# Exporting records 117840 to 122750
# Exporting records 122750 to 127660
# Exporting records 127660 to 132570
# Exporting records 132570 to 137480
# Exporting records 137480 to 142390
# Exporting records 142390 to 147300
# Exporting records 147300 to 152210
# Exporting records 152210 to 157120
# Exporting records 157120 to 162030
# Exporting records 162030 to 166940
# Exporting records 166940 to 171850
# Exporting records 171850 to 176760
# Exporting records 176760 to 181670
# Exporting records 181670 to 186580
# Exporting records 186580 to 191490
# Exporting records 191490 to 196400
# Exporting records 196400 to 201310
# Exporting records 201310 to 206220
# Exporting records 206220 to 211130
# Exporting records 211130 to 216040
# Exporting records 216040 to 220950
# Exporting records 220950 to 225860
# Exporting records 225860 to 230770
# Exporting records 230770 to 235680
# 12
# Processing tile: 48PUT
# record count: 235638, chunks: 48, step:4910
# projects/g4g-eaas/assets/intmd/eg_pt_to_patch_fc_tile_48PUT
# Exporting records 24550 to 29460
# Exporting records 29460 to 34370
# Exporting records 34370 to 39280
# Exporting records 39280 to 44190
# Exporting records 44190 to 49100
# Exporting records 49100 to 54010
# Exporting records 54010 to 58920
# Exporting records 58920 to 63830
# Exporting records 63830 to 68740
# Exporting records 68740 to 73650
# Exporting records 73650 to 78560
# Exporting records 78560 to 83470
# Exporting records 83470 to 88380
# Exporting records 88380 to 93290
# Exporting records 93290 to 98200
# Exporting records 98200 to 103110
# Exporting records 103110 to 108020
# Exporting records 108020 to 112930
# Exporting records 112930 to 117840
# Exporting records 117840 to 122750
# Exporting records 122750 to 127660
# Exporting records 127660 to 132570
# Exporting records 132570 to 137480
# Exporting records 137480 to 142390
# Exporting records 142390 to 147300
# Exporting records 147300 to 152210
# Exporting records 152210 to 157120
# Exporting records 157120 to 162030
# Exporting records 162030 to 166940
# Exporting records 166940 to 171850
# Exporting records 171850 to 176760
# Exporting records 176760 to 181670
# Exporting records 181670 to 186580
# Exporting records 186580 to 191490
# Exporting records 191490 to 196400
# Exporting records 196400 to 201310
# Exporting records 201310 to 206220
# Exporting records 206220 to 211130
# Exporting records 211130 to 216040
# Exporting records 216040 to 220950
# Exporting records 220950 to 225860
# Exporting records 225860 to 230770
# Exporting records 230770 to 235680
# 13
# Processing tile: 48PUU
# record count: 235624, chunks: 48, step:4909
# projects/g4g-eaas/assets/intmd/eg_pt_to_patch_fc_tile_48PUU
# Exporting records 24545 to 29454
# Exporting records 29454 to 34363
# Exporting records 34363 to 39272
# Exporting records 39272 to 44181
# Exporting records 44181 to 49090
# Exporting records 49090 to 53999
# Exporting records 53999 to 58908
# Exporting records 58908 to 63817
# Exporting records 63817 to 68726
# Exporting records 68726 to 73635
# Exporting records 73635 to 78544
# Exporting records 78544 to 83453
# Exporting records 83453 to 88362
# Exporting records 88362 to 93271
# Exporting records 93271 to 98180
# Exporting records 98180 to 103089
# Exporting records 103089 to 107998
# Exporting records 107998 to 112907
# Exporting records 112907 to 117816
# Exporting records 117816 to 122725
# Exporting records 122725 to 127634
# Exporting records 127634 to 132543
# Exporting records 132543 to 137452
# Exporting records 137452 to 142361
# Exporting records 142361 to 147270
# Exporting records 147270 to 152179
# Exporting records 152179 to 157088
# Exporting records 157088 to 161997
# Exporting records 161997 to 166906
# Exporting records 166906 to 171815
# Exporting records 171815 to 176724
# Exporting records 176724 to 181633
# Exporting records 181633 to 186542
# Exporting records 186542 to 191451
# Exporting records 191451 to 196360
# Exporting records 196360 to 201269
# Exporting records 201269 to 206178
# Exporting records 206178 to 211087
# Exporting records 211087 to 215996
# Exporting records 215996 to 220905
# Exporting records 220905 to 225814
# Exporting records 225814 to 230723
# Exporting records 230723 to 235632
# 15
# Processing tile: 48PXV
# record count: 235520, chunks: 48, step:4907
# projects/g4g-eaas/assets/intmd/eg_pt_to_patch_fc_tile_48PXV
# Exporting records 24535 to 29442
# Exporting records 29442 to 34349
# Exporting records 34349 to 39256
# Exporting records 39256 to 44163
# Exporting records 44163 to 49070
# Exporting records 49070 to 53977
# Exporting records 53977 to 58884
# Exporting records 58884 to 63791
# Exporting records 63791 to 68698
# Exporting records 68698 to 73605
# Exporting records 73605 to 78512
# Exporting records 78512 to 83419
# Exporting records 83419 to 88326
# Exporting records 88326 to 93233
# Exporting records 93233 to 98140
# Exporting records 98140 to 103047
# Exporting records 103047 to 107954
# Exporting records 107954 to 112861
# Exporting records 112861 to 117768
# Exporting records 117768 to 122675
# Exporting records 122675 to 127582
# Exporting records 127582 to 132489
# Exporting records 132489 to 137396
# Exporting records 137396 to 142303
# Exporting records 142303 to 147210
# Exporting records 147210 to 152117
# Exporting records 152117 to 157024
# Exporting records 157024 to 161931
# Exporting records 161931 to 166838
# Exporting records 166838 to 171745
# Exporting records 171745 to 176652
# Exporting records 176652 to 181559
# Exporting records 181559 to 186466
# Exporting records 186466 to 191373
# Exporting records 191373 to 196280
# Exporting records 196280 to 201187
# Exporting records 201187 to 206094
# Exporting records 206094 to 211001
# Exporting records 211001 to 215908
# Exporting records 215908 to 220815
# Exporting records 220815 to 225722
# Exporting records 225722 to 230629
# Exporting records 230629 to 235536
# 16
# Processing tile: 48PXA
# record count: 235520, chunks: 48, step:4907
# projects/g4g-eaas/assets/intmd/eg_pt_to_patch_fc_tile_48PXA
# Exporting records 24535 to 29442
# Exporting records 29442 to 34349
# Exporting records 34349 to 39256
# Exporting records 39256 to 44163
# Exporting records 44163 to 49070
# Exporting records 49070 to 53977
# Exporting records 53977 to 58884
# Exporting records 58884 to 63791
# Exporting records 63791 to 68698
# Exporting records 68698 to 73605
# Exporting records 73605 to 78512
# Exporting records 78512 to 83419
# Exporting records 83419 to 88326
# Exporting records 88326 to 93233
# Exporting records 93233 to 98140
# Exporting records 98140 to 103047
# Exporting records 103047 to 107954
# Exporting records 107954 to 112861
# Exporting records 112861 to 117768
# Exporting records 117768 to 122675
# Exporting records 122675 to 127582
# Exporting records 127582 to 132489
# Exporting records 132489 to 137396
# Exporting records 137396 to 142303
# Exporting records 142303 to 147210
# Exporting records 147210 to 152117
# Exporting records 152117 to 157024
# Exporting records 157024 to 161931
# Exporting records 161931 to 166838
# Exporting records 166838 to 171745
# Exporting records 171745 to 176652
# Exporting records 176652 to 181559
# Exporting records 181559 to 186466
# Exporting records 186466 to 191373
# Exporting records 191373 to 196280
# Exporting records 196280 to 201187
# Exporting records 201187 to 206094
# Exporting records 206094 to 211001
# Exporting records 211001 to 215908
# Exporting records 215908 to 220815
# Exporting records 220815 to 225722
# Exporting records 225722 to 230629
# Exporting records 230629 to 235536
# 17
# Processing tile: 48PXU
# record count: 235520, chunks: 48, step:4907
# projects/g4g-eaas/assets/intmd/eg_pt_to_patch_fc_tile_48PXU
# Exporting records 24535 to 29442
# Exporting records 29442 to 34349
# Exporting records 34349 to 39256
# Exporting records 39256 to 44163
# Exporting records 44163 to 49070
# Exporting records 49070 to 53977
# Exporting records 53977 to 58884
# Exporting records 58884 to 63791
# Exporting records 63791 to 68698
# Exporting records 68698 to 73605
# Exporting records 73605 to 78512
# Exporting records 78512 to 83419
# Exporting records 83419 to 88326
# Exporting records 88326 to 93233
# Exporting records 93233 to 98140
# Exporting records 98140 to 103047
# Exporting records 103047 to 107954
# Exporting records 107954 to 112861
# Exporting records 112861 to 117768
# Exporting records 117768 to 122675
# Exporting records 122675 to 127582
# Exporting records 127582 to 132489
# Exporting records 132489 to 137396
# Exporting records 137396 to 142303
# Exporting records 142303 to 147210
# Exporting records 147210 to 152117
# Exporting records 152117 to 157024
# Exporting records 157024 to 161931
# Exporting records 161931 to 166838
# Exporting records 166838 to 171745
# Exporting records 171745 to 176652
# Exporting records 176652 to 181559
# Exporting records 181559 to 186466
# Exporting records 186466 to 191373
# Exporting records 191373 to 196280
# Exporting records 196280 to 201187
# Exporting records 201187 to 206094
# Exporting records 206094 to 211001
# Exporting records 211001 to 215908
# Exporting records 215908 to 220815
# Exporting records 220815 to 225722
# Exporting records 225722 to 230629
# Exporting records 230629 to 235536
# 19
# Processing tile: 48PXT
# record count: 235520, chunks: 48, step:4907
# projects/g4g-eaas/assets/intmd/eg_pt_to_patch_fc_tile_48PXT
# Exporting records 24535 to 29442
# Exporting records 29442 to 34349
# Exporting records 34349 to 39256
# Exporting records 39256 to 44163
# Exporting records 44163 to 49070
# Exporting records 49070 to 53977
# Exporting records 53977 to 58884
# Exporting records 58884 to 63791
# Exporting records 63791 to 68698
# Exporting records 68698 to 73605
# Exporting records 73605 to 78512
# Exporting records 78512 to 83419
# Exporting records 83419 to 88326
# Exporting records 88326 to 93233
# Exporting records 93233 to 98140
# Exporting records 98140 to 103047
# Exporting records 103047 to 107954
# Exporting records 107954 to 112861
# Exporting records 112861 to 117768
# Exporting records 117768 to 122675
# Exporting records 122675 to 127582
# Exporting records 127582 to 132489
# Exporting records 132489 to 137396
# Exporting records 137396 to 142303
# Exporting records 142303 to 147210
# Exporting records 147210 to 152117
# Exporting records 152117 to 157024
# Exporting records 157024 to 161931
# Exporting records 161931 to 166838
# Exporting records 166838 to 171745
# Exporting records 171745 to 176652
# Exporting records 176652 to 181559
# Exporting records 181559 to 186466
# Exporting records 186466 to 191373
# Exporting records 191373 to 196280
# Exporting records 196280 to 201187
# Exporting records 201187 to 206094
# Exporting records 206094 to 211001
# Exporting records 211001 to 215908
# Exporting records 215908 to 220815
# Exporting records 220815 to 225722
# Exporting records 225722 to 230629
# Exporting records 230629 to 235536
# 20
# Processing tile: 48PUA
# record count: 235520, chunks: 48, step:4907
# projects/g4g-eaas/assets/intmd/eg_pt_to_patch_fc_tile_48PUA
# Exporting records 24535 to 29442
# Exporting records 29442 to 34349
# Exporting records 34349 to 39256
# Exporting records 39256 to 44163
# Exporting records 44163 to 49070
# Exporting records 49070 to 53977
# Exporting records 53977 to 58884
# Exporting records 58884 to 63791
# Exporting records 63791 to 68698
# Exporting records 68698 to 73605
# Exporting records 73605 to 78512
# Exporting records 78512 to 83419
# Exporting records 83419 to 88326
# Exporting records 88326 to 93233
# Exporting records 93233 to 98140
# Exporting records 98140 to 103047
# Exporting records 103047 to 107954
# Exporting records 107954 to 112861
# Exporting records 112861 to 117768
# Exporting records 117768 to 122675
# Exporting records 122675 to 127582
# Exporting records 127582 to 132489
# Exporting records 132489 to 137396
# Exporting records 137396 to 142303
# Exporting records 142303 to 147210
# Exporting records 147210 to 152117
# Exporting records 152117 to 157024
# Exporting records 157024 to 161931
# Exporting records 161931 to 166838
# Exporting records 166838 to 171745
# Exporting records 171745 to 176652
# Exporting records 176652 to 181559
# Exporting records 181559 to 186466
# Exporting records 186466 to 191373
# Exporting records 191373 to 196280
# Exporting records 196280 to 201187
# Exporting records 201187 to 206094
# Exporting records 206094 to 211001
# Exporting records 211001 to 215908
# Exporting records 215908 to 220815
# Exporting records 220815 to 225722
# Exporting records 225722 to 230629
# Exporting records 230629 to 235536
# 21
# Processing tile: 48PUV
# record count: 235520, chunks: 48, step:4907
# projects/g4g-eaas/assets/intmd/eg_pt_to_patch_fc_tile_48PUV
# Exporting records 24535 to 29442
# Exporting records 29442 to 34349
# Exporting records 34349 to 39256
# Exporting records 39256 to 44163
# Exporting records 44163 to 49070
# Exporting records 49070 to 53977
# Exporting records 53977 to 58884
# Exporting records 58884 to 63791
# Exporting records 63791 to 68698
# Exporting records 68698 to 73605
# Exporting records 73605 to 78512
# Exporting records 78512 to 83419
# Exporting records 83419 to 88326
# Exporting records 88326 to 93233
# Exporting records 93233 to 98140
# Exporting records 98140 to 103047
# Exporting records 103047 to 107954
# Exporting records 107954 to 112861
# Exporting records 112861 to 117768
# Exporting records 117768 to 122675
# Exporting records 122675 to 127582
# Exporting records 127582 to 132489
# Exporting records 132489 to 137396
# Exporting records 137396 to 142303
# Exporting records 142303 to 147210
# Exporting records 147210 to 152117
# Exporting records 152117 to 157024
# Exporting records 157024 to 161931
# Exporting records 161931 to 166838
# Exporting records 166838 to 171745
# Exporting records 171745 to 176652
# Exporting records 176652 to 181559
# Exporting records 181559 to 186466
# Exporting records 186466 to 191373
# Exporting records 191373 to 196280
# Exporting records 196280 to 201187
# Exporting records 201187 to 206094
# Exporting records 206094 to 211001
# Exporting records 211001 to 215908
# Exporting records 215908 to 220815
# Exporting records 220815 to 225722
# Exporting records 225722 to 230629
# Exporting records 230629 to 235536
# 22
# Processing tile: 48PXB
# record count: 235516, chunks: 48, step:4907
# projects/g4g-eaas/assets/intmd/eg_pt_to_patch_fc_tile_48PXB
# Exporting records 24535 to 29442
# Exporting records 29442 to 34349
# Exporting records 34349 to 39256
# Exporting records 39256 to 44163
# Exporting records 44163 to 49070
# Exporting records 49070 to 53977
# Exporting records 53977 to 58884
# Exporting records 58884 to 63791
# Exporting records 63791 to 68698
# Exporting records 68698 to 73605
# Exporting records 73605 to 78512
# Exporting records 78512 to 83419
# Exporting records 83419 to 88326
# Exporting records 88326 to 93233
# Exporting records 93233 to 98140
# Exporting records 98140 to 103047
# Exporting records 103047 to 107954
# Exporting records 107954 to 112861
# Exporting records 112861 to 117768
# Exporting records 117768 to 122675
# Exporting records 122675 to 127582
# Exporting records 127582 to 132489
# Exporting records 132489 to 137396
# Exporting records 137396 to 142303
# Exporting records 142303 to 147210
# Exporting records 147210 to 152117
# Exporting records 152117 to 157024
# Exporting records 157024 to 161931
# Exporting records 161931 to 166838
# Exporting records 166838 to 171745
# Exporting records 171745 to 176652
# Exporting records 176652 to 181559
# Exporting records 181559 to 186466
# Exporting records 186466 to 191373
# Exporting records 191373 to 196280
# Exporting records 196280 to 201187
# Exporting records 201187 to 206094
# Exporting records 206094 to 211001
# Exporting records 211001 to 215908
# Exporting records 215908 to 220815
# Exporting records 220815 to 225722
# Exporting records 225722 to 230629
# Exporting records 230629 to 235536
# 25
# Processing tile: 48PTT
# record count: 235393, chunks: 48, step:4905
# projects/g4g-eaas/assets/intmd/eg_pt_to_patch_fc_tile_48PTT
# Exporting records 24525 to 29430
# Exporting records 29430 to 34335
# Exporting records 34335 to 39240
# Exporting records 39240 to 44145
# Exporting records 44145 to 49050
# Exporting records 49050 to 53955
# Exporting records 53955 to 58860
# Exporting records 58860 to 63765
# Exporting records 63765 to 68670
# Exporting records 68670 to 73575
# Exporting records 73575 to 78480
# Exporting records 78480 to 83385
# Exporting records 83385 to 88290
# Exporting records 88290 to 93195
# Exporting records 93195 to 98100
# Exporting records 98100 to 103005
# Exporting records 103005 to 107910
# Exporting records 107910 to 112815
# Exporting records 112815 to 117720
# Exporting records 117720 to 122625
# Exporting records 122625 to 127530
# Exporting records 127530 to 132435
# Exporting records 132435 to 137340
# Exporting records 137340 to 142245
# Exporting records 142245 to 147150
# Exporting records 147150 to 152055
# Exporting records 152055 to 156960
# Exporting records 156960 to 161865
# Exporting records 161865 to 166770
# Exporting records 166770 to 171675
# Exporting records 171675 to 176580
# Exporting records 176580 to 181485
# Exporting records 181485 to 186390
# Exporting records 186390 to 191295
# Exporting records 191295 to 196200
# Exporting records 196200 to 201105
# Exporting records 201105 to 206010
# Exporting records 206010 to 210915
# Exporting records 210915 to 215820
# Exporting records 215820 to 220725
# Exporting records 220725 to 225630
# Exporting records 225630 to 230535
# Exporting records 230535 to 235440
# 26
# Processing tile: 48PTU
# record count: 235383, chunks: 48, step:4904
# projects/g4g-eaas/assets/intmd/eg_pt_to_patch_fc_tile_48PTU
# Exporting records 24520 to 29424
# Exporting records 29424 to 34328
# Exporting records 34328 to 39232
# Exporting records 39232 to 44136
# Exporting records 44136 to 49040
# Exporting records 49040 to 53944
# Exporting records 53944 to 58848
# Exporting records 58848 to 63752
# Exporting records 63752 to 68656
# Exporting records 68656 to 73560
# Exporting records 73560 to 78464
# Exporting records 78464 to 83368
# Exporting records 83368 to 88272
# Exporting records 88272 to 93176
# Exporting records 93176 to 98080
# Exporting records 98080 to 102984
# Exporting records 102984 to 107888
# Exporting records 107888 to 112792
# Exporting records 112792 to 117696
# Exporting records 117696 to 122600
# Exporting records 122600 to 127504
# Exporting records 127504 to 132408
# Exporting records 132408 to 137312
# Exporting records 137312 to 142216
# Exporting records 142216 to 147120
# Exporting records 147120 to 152024
# Exporting records 152024 to 156928
# Exporting records 156928 to 161832
# Exporting records 161832 to 166736
# Exporting records 166736 to 171640
# Exporting records 171640 to 176544
# Exporting records 176544 to 181448
# Exporting records 181448 to 186352
# Exporting records 186352 to 191256
# Exporting records 191256 to 196160
# Exporting records 196160 to 201064
# Exporting records 201064 to 205968
# Exporting records 205968 to 210872
# Exporting records 210872 to 215776
# Exporting records 215776 to 220680
# Exporting records 220680 to 225584
# Exporting records 225584 to 230488
# Exporting records 230488 to 235392
# 27
# Processing tile: 48PTV
# record count: 235335, chunks: 48, step:4903
# projects/g4g-eaas/assets/intmd/eg_pt_to_patch_fc_tile_48PTV
# Exporting records 24515 to 29418
# Exporting records 29418 to 34321
# Exporting records 34321 to 39224
# Exporting records 39224 to 44127
# Exporting records 44127 to 49030
# Exporting records 49030 to 53933
# Exporting records 53933 to 58836
# Exporting records 58836 to 63739
# Exporting records 63739 to 68642
# Exporting records 68642 to 73545
# Exporting records 73545 to 78448
# Exporting records 78448 to 83351
# Exporting records 83351 to 88254
# Exporting records 88254 to 93157
# Exporting records 93157 to 98060
# Exporting records 98060 to 102963
# Exporting records 102963 to 107866
# Exporting records 107866 to 112769
# Exporting records 112769 to 117672
# Exporting records 117672 to 122575
# Exporting records 122575 to 127478
# Exporting records 127478 to 132381
# Exporting records 132381 to 137284
# Exporting records 137284 to 142187
# Exporting records 142187 to 147090
# Exporting records 147090 to 151993
# Exporting records 151993 to 156896
# Exporting records 156896 to 161799
# Exporting records 161799 to 166702
# Exporting records 166702 to 171605
# Exporting records 171605 to 176508
# Exporting records 176508 to 181411
# Exporting records 181411 to 186314
# Exporting records 186314 to 191217
# Exporting records 191217 to 196120
# Exporting records 196120 to 201023
# Exporting records 201023 to 205926
# Exporting records 205926 to 210829
# Exporting records 210829 to 215732
# Exporting records 215732 to 220635
# Exporting records 220635 to 225538
# Exporting records 225538 to 230441
# Exporting records 230441 to 235344
# 28
# Processing tile: 48PYU
# record count: 235331, chunks: 48, step:4903
# projects/g4g-eaas/assets/intmd/eg_pt_to_patch_fc_tile_48PYU
# Exporting records 24515 to 29418
# Exporting records 29418 to 34321
# Exporting records 34321 to 39224
# Exporting records 39224 to 44127
# Exporting records 44127 to 49030
# Exporting records 49030 to 53933
# Exporting records 53933 to 58836
# Exporting records 58836 to 63739
# Exporting records 63739 to 68642
# Exporting records 68642 to 73545
# Exporting records 73545 to 78448
# Exporting records 78448 to 83351
# Exporting records 83351 to 88254
# Exporting records 88254 to 93157
# Exporting records 93157 to 98060
# Exporting records 98060 to 102963
# Exporting records 102963 to 107866
# Exporting records 107866 to 112769
# Exporting records 112769 to 117672
# Exporting records 117672 to 122575
# Exporting records 122575 to 127478
# Exporting records 127478 to 132381
# Exporting records 132381 to 137284
# Exporting records 137284 to 142187
# Exporting records 142187 to 147090
# Exporting records 147090 to 151993
# Exporting records 151993 to 156896
# Exporting records 156896 to 161799
# Exporting records 161799 to 166702
# Exporting records 166702 to 171605
# Exporting records 171605 to 176508
# Exporting records 176508 to 181411
# Exporting records 181411 to 186314
# Exporting records 186314 to 191217
# Exporting records 191217 to 196120
# Exporting records 196120 to 201023
# Exporting records 201023 to 205926
# Exporting records 205926 to 210829
# Exporting records 210829 to 215732
# Exporting records 215732 to 220635
# Exporting records 220635 to 225538
# Exporting records 225538 to 230441
# Exporting records 230441 to 235344
# 29
# Processing tile: 48PTA
# record count: 235319, chunks: 48, step:4903
# projects/g4g-eaas/assets/intmd/eg_pt_to_patch_fc_tile_48PTA
# Exporting records 24515 to 29418
# Exporting records 29418 to 34321
# Exporting records 34321 to 39224
# Exporting records 39224 to 44127
# Exporting records 44127 to 49030
# Exporting records 49030 to 53933
# Exporting records 53933 to 58836
# Exporting records 58836 to 63739
# Exporting records 63739 to 68642
# Exporting records 68642 to 73545
# Exporting records 73545 to 78448
# Exporting records 78448 to 83351
# Exporting records 83351 to 88254
# Exporting records 88254 to 93157
# Exporting records 93157 to 98060
# Exporting records 98060 to 102963
# Exporting records 102963 to 107866
# Exporting records 107866 to 112769
# Exporting records 112769 to 117672
# Exporting records 117672 to 122575
# Exporting records 122575 to 127478
# Exporting records 127478 to 132381
# Exporting records 132381 to 137284
# Exporting records 137284 to 142187
# Exporting records 142187 to 147090
# Exporting records 147090 to 151993
# Exporting records 151993 to 156896
# Exporting records 156896 to 161799
# Exporting records 161799 to 166702
# Exporting records 166702 to 171605
# Exporting records 171605 to 176508
# Exporting records 176508 to 181411
# Exporting records 181411 to 186314
# Exporting records 186314 to 191217
# Exporting records 191217 to 196120
# Exporting records 196120 to 201023
# Exporting records 201023 to 205926
# Exporting records 205926 to 210829
# Exporting records 210829 to 215732
# Exporting records 215732 to 220635
# Exporting records 220635 to 225538
# Exporting records 225538 to 230441
# Exporting records 230441 to 235344
# 30
# Processing tile: 48PYV
# record count: 235318, chunks: 48, step:4903
# projects/g4g-eaas/assets/intmd/eg_pt_to_patch_fc_tile_48PYV
# Exporting records 24515 to 29418
# Exporting records 29418 to 34321
# Exporting records 34321 to 39224
# Exporting records 39224 to 44127
# Exporting records 44127 to 49030
# Exporting records 49030 to 53933
# Exporting records 53933 to 58836
# Exporting records 58836 to 63739
# Exporting records 63739 to 68642
# Exporting records 68642 to 73545
# Exporting records 73545 to 78448
# Exporting records 78448 to 83351
# Exporting records 83351 to 88254
# Exporting records 88254 to 93157
# Exporting records 93157 to 98060
# Exporting records 98060 to 102963
# Exporting records 102963 to 107866
# Exporting records 107866 to 112769
# Exporting records 112769 to 117672
# Exporting records 117672 to 122575
# Exporting records 122575 to 127478
# Exporting records 127478 to 132381
# Exporting records 132381 to 137284
# Exporting records 137284 to 142187
# Exporting records 142187 to 147090
# Exporting records 147090 to 151993
# Exporting records 151993 to 156896
# Exporting records 156896 to 161799
# Exporting records 161799 to 166702
# Exporting records 166702 to 171605
# Exporting records 171605 to 176508
# Exporting records 176508 to 181411
# Exporting records 181411 to 186314
# Exporting records 186314 to 191217
# Exporting records 191217 to 196120
# Exporting records 196120 to 201023
# Exporting records 201023 to 205926
# Exporting records 205926 to 210829
# Exporting records 210829 to 215732
# Exporting records 215732 to 220635
# Exporting records 220635 to 225538
# Exporting records 225538 to 230441
# Exporting records 230441 to 235344
# 31
# Processing tile: 48PYA
# record count: 235296, chunks: 48, step:4902
# projects/g4g-eaas/assets/intmd/eg_pt_to_patch_fc_tile_48PYA
# Exporting records 24510 to 29412
# Exporting records 29412 to 34314
# Exporting records 34314 to 39216
# Exporting records 39216 to 44118
# Exporting records 44118 to 49020
# Exporting records 49020 to 53922
# Exporting records 53922 to 58824
# Exporting records 58824 to 63726
# Exporting records 63726 to 68628
# Exporting records 68628 to 73530
# Exporting records 73530 to 78432
# Exporting records 78432 to 83334
# Exporting records 83334 to 88236
# Exporting records 88236 to 93138
# Exporting records 93138 to 98040
# Exporting records 98040 to 102942
# Exporting records 102942 to 107844
# Exporting records 107844 to 112746
# Exporting records 112746 to 117648
# Exporting records 117648 to 122550
# Exporting records 122550 to 127452
# Exporting records 127452 to 132354
# Exporting records 132354 to 137256
# Exporting records 137256 to 142158
# Exporting records 142158 to 147060
# Exporting records 147060 to 151962
# Exporting records 151962 to 156864
# Exporting records 156864 to 161766
# Exporting records 161766 to 166668
# Exporting records 166668 to 171570
# Exporting records 171570 to 176472
# Exporting records 176472 to 181374
# Exporting records 181374 to 186276
# Exporting records 186276 to 191178
# Exporting records 191178 to 196080
# Exporting records 196080 to 200982
# Exporting records 200982 to 205884
# Exporting records 205884 to 210786
# Exporting records 210786 to 215688
# Exporting records 215688 to 220590
# Exporting records 220590 to 225492
# Exporting records 225492 to 230394
# Exporting records 230394 to 235296
# 34
# Processing tile: 47PRQ
# record count: 234942, chunks: 47, step:4999
# projects/g4g-eaas/assets/intmd/eg_pt_to_patch_fc_tile_47PRQ
# Exporting records 24995 to 29994
# Exporting records 29994 to 34993
# Exporting records 34993 to 39992
# Exporting records 39992 to 44991
# Exporting records 44991 to 49990
# Exporting records 49990 to 54989
# Exporting records 54989 to 59988
# Exporting records 59988 to 64987
# Exporting records 64987 to 69986
# Exporting records 69986 to 74985
# Exporting records 74985 to 79984
# Exporting records 79984 to 84983
# Exporting records 84983 to 89982
# Exporting records 89982 to 94981
# Exporting records 94981 to 99980
# Exporting records 99980 to 104979
# Exporting records 104979 to 109978
# Exporting records 109978 to 114977
# Exporting records 114977 to 119976
# Exporting records 119976 to 124975
# Exporting records 124975 to 129974
# Exporting records 129974 to 134973
# Exporting records 134973 to 139972
# Exporting records 139972 to 144971
# Exporting records 144971 to 149970
# Exporting records 149970 to 154969
# Exporting records 154969 to 159968
# Exporting records 159968 to 164967
# Exporting records 164967 to 169966
# Exporting records 169966 to 174965
# Exporting records 174965 to 179964
# Exporting records 179964 to 184963
# Exporting records 184963 to 189962
# Exporting records 189962 to 194961
# Exporting records 194961 to 199960
# Exporting records 199960 to 204959
# Exporting records 204959 to 209958
# Exporting records 209958 to 214957
# Exporting records 214957 to 219956
# Exporting records 219956 to 224955
# Exporting records 224955 to 229954
# Exporting records 229954 to 234953
# 35
# Processing tile: 47PRR
# record count: 234927, chunks: 47, step:4999
# projects/g4g-eaas/assets/intmd/eg_pt_to_patch_fc_tile_47PRR
# Exporting records 24995 to 29994
# Exporting records 29994 to 34993
# Exporting records 34993 to 39992
# Exporting records 39992 to 44991
# Exporting records 44991 to 49990
# Exporting records 49990 to 54989
# Exporting records 54989 to 59988
# Exporting records 59988 to 64987
# Exporting records 64987 to 69986
# Exporting records 69986 to 74985
# Exporting records 74985 to 79984
# Exporting records 79984 to 84983
# Exporting records 84983 to 89982
# Exporting records 89982 to 94981
# Exporting records 94981 to 99980
# Exporting records 99980 to 104979
# Exporting records 104979 to 109978
# Exporting records 109978 to 114977
# Exporting records 114977 to 119976
# Exporting records 119976 to 124975
# Exporting records 124975 to 129974
# Exporting records 129974 to 134973
# Exporting records 134973 to 139972
# Exporting records 139972 to 144971
# Exporting records 144971 to 149970
# Exporting records 149970 to 154969
# Exporting records 154969 to 159968
# Exporting records 159968 to 164967
# Exporting records 164967 to 169966
# Exporting records 169966 to 174965
# Exporting records 174965 to 179964
# Exporting records 179964 to 184963
# Exporting records 184963 to 189962
# Exporting records 189962 to 194961
# Exporting records 194961 to 199960
# Exporting records 199960 to 204959
# Exporting records 204959 to 209958
# Exporting records 209958 to 214957
# Exporting records 214957 to 219956
# Exporting records 219956 to 224955
# Exporting records 224955 to 229954
# Exporting records 229954 to 234953

# %% [markdown]
# # DEBUGGING

# %%
# EG patch embeddings are produced from 32x32 px patches of Sentinel-2 (so 320m^2 image footprints), 
# efm_patch_embed = reduce_nested(efm.mosaic(),
#                            eg_patches_asset,
#                            reducer=ee.Reducer.mean(),
#                            scale=10,
#                            crs='EPSG:4326',
#                            crs_transform=None,
#                            best_effort=True,
#                            maxPixels=1e13,
#                            tileScale=16
#                           )

# pprint(efm_patch_embed.first().getInfo()['properties'])

# # Apply the function to the feature collection
# updated_fc = efm_patch_embed.map(embedding_array_prop)
# updated_fc = updated_fc.select(['id','tile','geometry', 'embedding_efm','random'])
# # Print the first feature to verify
# pprint(updated_fc.first().getInfo())


# updated_fc = updated_fc.map(convert_embedding_to_string)
# pprint(updated_fc.first().get('embedding_efm').getInfo())

# m = geemap.Map()
# m.addLayer(efm, {}, "EFM",False)
# m.addLayer(eg_patches_asset, {}, "EG patches asset",False)
# m.addLayer(efm_patch_embed.first(), {}, "EFM patch embedding first")
# m.centerObject(efm_patch_embed.first(), 12)
# m
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
# is it the slicing/chunking of the FC itself that is inefficient? 
# task = ee.batch.Export.table.toAsset(
#     collection=updated_fc.limit(50,'random',True),
#     description='efm_patch_embed_from_eg_patchasset_Asset_lim50',
#     assetId='projects/g4g-eaas/assets/efm_patch_embed_from_eg_patchasset_lim50'
# )
# task.start()

# is exporting to BQ less effient than exporting to asset?
# task = ee.batch.Export.table.toBigQuery(
#             collection=updated_fc.limit(50,'random',True),
#             description="efm_patch_embed_from_eg_patchasset_BQ_lim50",
#             table='g4g-eaas.embeddings_sea.efm_patch_embed_from_eg_patchasset_BQ_lim50',
#             append=True,
#             selectors=['id', 'tile', 'geometry', 'embedding_efm']
#         )
# task.start()
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
# using .random() and then .filter() to chunk the feature collection into smaller export chunks
# import math
# chunks = 1000
# for tile in records_tile.keys():
#     record_count = records_tile[tile]
#     step = 1/chunks
#     chunk_size = math.ceil(record_count/chunks)
#     print(f"record count: {record_count}, chunks: {chunks}, chunk_size: {chunk_size}, step:{step}")
    
#     this_tile = (
#         updated_fc.filter(ee.Filter.eq('tile', tile))
#         .randomColumn('random', 0,'uniform',['id'])
#                  )
    
#     for i in range(chunks):
#         start = (i * step)
#         end = ((i + 1) * step)
#         print(start, end)
#         filtered_fc = this_tile.filter(ee.Filter.rangeContains('random', start, end))
#         task = ee.batch.Export.table.toBigQuery(
#             collection=filtered_fc,
#             description=f"EG_embeddings_efm_{start}_{end}",
#             table='g4g-eaas.embeddings_sea.earthgenome_efm_fc_chunked',
#             append=True,
#             selectors=['id', 'tile', 'geometry', 'embedding_efm'],
#         )
#         task.start()
#         if start > 0.0:
#             break
    
    
#     break
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
# why are fc chunks empty upon export?...

# this_tile = updated_fc.filter(ee.Filter.eq('tile', tile)).randomColumn('random', 0,'uniform')
# print(this_tile.limit(1000,'random',True).size().getInfo())
# task = ee.batch.Export.table.toAsset(
#             collection=this_tile.limit(1000, 'random',True),
#             description=f"eg_embeddings_efm_randFC_lim1000",
#             assetId='projects/g4g-eaas/assets/eg_embeddings_efm_randFC_lim1000',
#             # table='g4g-eaas.embeddings_sea.earthgenome_efm_fc_chunked',
#             # append=True,
#             selectors=['id', 'tile', 'geometry', 'embedding_efm']
#         )
# task.start()
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
# bq_task = ee.batch.Export.table.toBigQuery(
#     updated_fc,
#     description='efm_agg_embed_on_eg_patches_ones2tile',
#     table='g4g-eaas.embeddings_sea.efm_agg_embed_on_eg_patches_ones2tile',
#     append=True,
#     selectors=['id', 'tile', 'geo', 'embedding_efm'],)
# bq_task.start()
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
