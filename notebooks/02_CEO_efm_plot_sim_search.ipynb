# %% [markdown]
# ### Performing Similarity Search on CEO plots involves picking a target plot and pointing the vector_search fn to the BQ table that contains the CEO plot's embeddings

# %%
from utils import *

project = "collect-earth-online"
dataset='sim_search_test'

# %%
table = "ceo-Okayama-Tile-5-v2-plot-data-2025-07-22_2022_2022_437_pp" # BQ vector search table
result_df = vector_search('54', # target plotid
                          10, # return top 10 matches
                          project,
                          dataset,
                          table)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
result_df
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
#   target_plotid base_plotid  distance
# 0            54          60  0.066659
# 1            54          42  0.069910
# 2            54          14  0.076291
# 3            54          41  0.082364
# ...

# %% [markdown]
# Currently `vector_search` returns the result as a pandas.DataFrame, but we can change it to returning a JSON string or something more easily passable in a REST API setting
#
# After receiving the sim search result, we'd want to do a join on the actual CEO postgres table to add back in all of each plot's CEO fields and display location and attribute info visually
